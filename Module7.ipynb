# %% [markdown]
# # Hands on: Creating context-specific mechanistic networks from experimental data and prior knowledge

# %% [markdown]
# This Python notebook serves as an example of how users can use their own datasets and integrate them with INDRA to provide meaningful interpretation.  We start with bringing our own MSstats dataset that consists of a list of proteins alongside their p-values.  We use p-values to filter which genes we query INDRA with.

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## STEP 1: Import MSstats Dataset

# %% [markdown]
# First, we will import MSstats datasets as pandas dataframes.  The MSstats dataset consist of the output of the MSstats groupComparison function, which consists of protein p-values.
#
# We filter the datasets to smaller sizes based on p-value.  You can adjust those parameters as well.

# %%
import pandas as pd

P_VALUE_LOGFC_PATH = "../data/model.csv" # Set this path yourself
LABELS_FILTER = ["DMSO-DbET6"]

P_VALUE_FILTER = 0.05 # Adjust this yourself

def construct_pvalue_logfc_df(filename):
    """Return a filtered data frame from the given data file."""
    pandas_df = pd.read_csv(filename)
    pandas_df = pandas_df[pandas_df['issue'].isnull()]
    pandas_df = pandas_df[pandas_df['adj.pvalue'] < P_VALUE_FILTER]
    pandas_df = pandas_df[pandas_df['Label'].isin(LABELS_FILTER)]
    return pandas_df

pvalue_logfc_df = construct_pvalue_logfc_df(P_VALUE_LOGFC_PATH)
pvalue_logfc_df
# Out:
#             Protein       Label        log2FC        SE     Tvalue     DF  \
# 19890    BRD2_HUMAN  DMSO-DbET6   2.046185244  0.114339  17.895836  260.0
# 19935    BRD3_HUMAN  DMSO-DbET6   3.333427936  0.126571  26.336522  257.0
# 19980    BRD4_HUMAN  DMSO-DbET6   2.668934662  0.101283  26.351317  257.0
# 27900   CEBPZ_HUMAN  DMSO-DbET6  -0.291058829  0.074340  -3.915236  260.0
# 37530   CRNL1_HUMAN  DMSO-DbET6  -0.268053808  0.069816  -3.839419  260.0
# 41580   DAZP1_HUMAN  DMSO-DbET6   0.617508071  0.099537   6.203818  260.0
# 66060   FUBP2_HUMAN  DMSO-DbET6   0.291044501  0.077226   3.768747  260.0
# 66105   FUBP3_HUMAN  DMSO-DbET6   0.300409541  0.069882   4.298798  260.0
# 72855   GTPB4_HUMAN  DMSO-DbET6  -0.344028893  0.087806  -3.918077  260.0
# 75735   HEAT3_HUMAN  DMSO-DbET6  -0.409028514  0.100056  -4.087980  260.0
# 77985   HNRPD_HUMAN  DMSO-DbET6   0.236133866  0.049974   4.725139  260.0
# 92790    KRR1_HUMAN  DMSO-DbET6  -0.206019868  0.048706  -4.229846  260.0
# 119520   NOP2_HUMAN  DMSO-DbET6  -0.260985294  0.045615  -5.721467  260.0
# 137745  PP1R8_HUMAN  DMSO-DbET6   0.358282468  0.069056   5.188314  260.0
# 140535  PRP18_HUMAN  DMSO-DbET6   0.485713404  0.120799   4.020834  260.0
# 145440    QKI_HUMAN  DMSO-DbET6   0.336984673  0.055130   6.112567  260.0
# 196155   TIA1_HUMAN  DMSO-DbET6   0.476791144  0.105361   4.525306  260.0
# 210195  UTP15_HUMAN  DMSO-DbET6   -0.59354411  0.079188  -7.495409  260.0
# 214515  WDR12_HUMAN  DMSO-DbET6  -0.217539679  0.049685  -4.378405  260.0
# 214965  WDR43_HUMAN  DMSO-DbET6  -0.502419318  0.070364  -7.140333  260.0
# 215505  WDR75_HUMAN  DMSO-DbET6  -0.393941989  0.091846  -4.289155  260.0
#
#               pvalue    adj.pvalue issue  MissingPercentage  \
# 19890   0.000000e+00  0.000000e+00   NaN           0.310067
# 19935   0.000000e+00  0.000000e+00   NaN           0.252349
# 19980   0.000000e+00  0.000000e+00   NaN           0.118121
# 27900   1.154420e-04  3.005139e-02   NaN           0.059060
# 37530   1.549580e-04  3.832114e-02   NaN           0.027517
# 41580   2.159950e-09  1.780518e-06   NaN           0.286577
# 66060   2.030530e-04  4.782372e-02   NaN           0.017450
# 66105   2.430235e-05  8.941156e-03   NaN           0.095302
# 72855   1.141660e-04  3.005139e-02   NaN           0.020134
# 75735   5.804139e-05  1.794204e-02   NaN           0.127517
# 77985   3.768760e-06  1.864029e-03   NaN           0.142282
# 92790   3.242996e-05  1.069324e-02   NaN           0.010067
# 119520  2.899095e-08  1.792365e-05   NaN           0.092617
# 137745  4.275951e-07  2.349870e-04   NaN           0.045638
# 140535  7.603588e-05  2.212197e-02   NaN           0.049664
# 145440  3.570594e-09  2.522880e-06   NaN           0.000000
# 196155  9.182867e-06  4.128951e-03   NaN           0.058389
# 210195  1.039169e-12  1.284932e-09   NaN           0.300000
# 214515  1.733909e-05  7.146595e-03   NaN           0.001342
# 214965  9.313883e-12  9.213293e-09   NaN           0.144966
# 215505  2.530857e-05  8.941156e-03   NaN           0.324161
#
#         ImputationPercentage
# 19890                    0.0
# 19935                    0.0
# 19980                    0.0
# 27900                    0.0
# 37530                    0.0
# 41580                    0.0
# 66060                    0.0
# 66105                    0.0
# 72855                    0.0
# 75735                    0.0
# 77985                    0.0
# 92790                    0.0
# 119520                   0.0
# 137745                   0.0
# 140535                   0.0
# 145440                   0.0
# 196155                   0.0
# 210195                   0.0
# 214515                   0.0
# 214965                   0.0
# 215505                   0.0

# %%
sorted(set(pvalue_logfc_df.Label))
# Out:
# ['DMSO-DbET6']

# %% [markdown]
# ## STEP 2: ID CONVERSION

# %% [markdown]
# INDRA Cogex only accepts HGNC IDs at the time of this writing.  However, the dataset provided in the example above contains uniprot mnemonic IDs.
#
# Luckily, INDRA has code to convert uniprot mnemonic IDs into HGNC ids. For now, we will store this mapping in a separate dictionary

# %%
from indra.databases import uniprot_client

def uniprot_to_hgnc_id(uniprot_mnemonic):
    """Get an HGNC ID from a UniProt mnemonic."""
    uniprot_id = uniprot_client.get_id_from_mnemonic(uniprot_mnemonic)
    if uniprot_id:
        return uniprot_client.get_hgnc_id(uniprot_id)
    else:
        return None

uniprot_to_hgnc_id("BRD2_HUMAN")
# Out:
# '1103'

# %%
def uniprot_to_hgnc_gene_name(uniprot_mnemonic):
    """Get an HGNC gene name from a UniProt mnemonic."""
    uniprot_id = uniprot_client.get_gene_name(uniprot_mnemonic)
    return uniprot_id
uniprot_to_hgnc_gene_name("BRD2_HUMAN")
# Out:
# 'BRD2'

# %%
def create_hgnc_id_to_uniprot_mapping(pandas_df):
    mappings = {}
    for protein in pandas_df['Protein'].unique():
        mappings[uniprot_to_hgnc_id(protein)] = protein
    return mappings

hgnc_id_to_uniprot_mapping = create_hgnc_id_to_uniprot_mapping(pvalue_logfc_df)
hgnc_id_to_uniprot_mapping
# Out:
# {'1103': 'BRD2_HUMAN',
#  '1104': 'BRD3_HUMAN',
#  '13575': 'BRD4_HUMAN',
#  '24218': 'CEBPZ_HUMAN',
#  '15762': 'CRNL1_HUMAN',
#  '2683': 'DAZP1_HUMAN',
#  '6316': 'FUBP2_HUMAN',
#  '4005': 'FUBP3_HUMAN',
#  '21535': 'GTPB4_HUMAN',
#  '26087': 'HEAT3_HUMAN',
#  '5036': 'HNRPD_HUMAN',
#  '5176': 'KRR1_HUMAN',
#  '7867': 'NOP2_HUMAN',
#  '9296': 'PP1R8_HUMAN',
#  '17351': 'PRP18_HUMAN',
#  '21100': 'QKI_HUMAN',
#  '11802': 'TIA1_HUMAN',
#  '25758': 'UTP15_HUMAN',
#  '14098': 'WDR12_HUMAN',
#  '28945': 'WDR43_HUMAN',
#  '25725': 'WDR75_HUMAN'}

# %%
def create_hgnc_gene_name_to_uniprot_mapping(pandas_df):
    mappings = {}
    for protein in pandas_df['Protein'].unique():
        mappings[uniprot_to_hgnc_gene_name(protein)] = protein
    return mappings

hgnc_gene_name_to_uniprot_mapping = create_hgnc_gene_name_to_uniprot_mapping(pvalue_logfc_df)
hgnc_gene_name_to_uniprot_mapping
# Out:
# {'BRD2': 'BRD2_HUMAN',
#  'BRD3': 'BRD3_HUMAN',
#  'BRD4': 'BRD4_HUMAN',
#  'CEBPZ': 'CEBPZ_HUMAN',
#  'CRNKL1': 'CRNL1_HUMAN',
#  'DAZAP1': 'DAZP1_HUMAN',
#  'KHSRP': 'FUBP2_HUMAN',
#  'FUBP3': 'FUBP3_HUMAN',
#  'GTPBP4': 'GTPB4_HUMAN',
#  'HEATR3': 'HEAT3_HUMAN',
#  'HNRNPD': 'HNRPD_HUMAN',
#  'KRR1': 'KRR1_HUMAN',
#  'NOP2': 'NOP2_HUMAN',
#  'PPP1R8': 'PP1R8_HUMAN',
#  'PRPF18': 'PRP18_HUMAN',
#  'QKI': 'QKI_HUMAN',
#  'TIA1': 'TIA1_HUMAN',
#  'UTP15': 'UTP15_HUMAN',
#  'WDR12': 'WDR12_HUMAN',
#  'WDR43': 'WDR43_HUMAN',
#  'WDR75': 'WDR75_HUMAN'}

# %% [markdown]
# ## STEP 3: QUERY INDRA COGEX

# %% [markdown]
# Using INDRA Cogex, we can extract subnetwork relationships among the proteins from the MSstats output.

# %%
import requests

def query_indra_subnetwork(groundings):
    """Return a list INDRA subnetwork relations based on a list of groundings."""
    res = requests.post(
        'https://discovery.indra.bio/api/indra_subnetwork_relations',
        json={'nodes': groundings}
    )
    return res.json()

# %%
groundings = []
for hgnc_id in hgnc_id_to_uniprot_mapping:
    groundings.append(('HGNC', hgnc_id))
subnetwork_relations = query_indra_subnetwork(groundings)
subnetwork_relations[0]
# Out:
# {'data': {'belief': 0.65,
#   'evidence_count': 1,
#   'has_database_evidence': False,
#   'has_reader_evidence': True,
#   'has_retracted_evidence': False,
#   'medscan_only': False,
#   'source_counts': '{"sparser": 1}',
#   'sparser_only': True,
#   'stmt_hash': 6100415255007272,
#   'stmt_json': '{"type": "Complex", "members": [{"name": "RAD21", "db_refs": {"UP": "O60216", "TEXT": "RAD21", "HGNC": "9811", "EGID": "5885"}}, {"name": "BRD2", "db_refs": {"UP": "P25440", "TEXT": "BRD2", "HGNC": "1103", "EGID": "6046"}}, {"name": "BRD4", "db_refs": {"UP": "O60885", "TEXT": "BRD4", "HGNC": "13575", "EGID": "23476"}}], "belief": 0.65, "evidence": [{"source_api": "sparser", "pmid": "28107481", "text": "However, we were unable to demonstrate any direct physical interaction between BRD2 or BRD4 with cohesin subunit RAD21 ( xref ), suggesting the conformational control of KSHV latency involves additional factors.", "annotations": {"found_by": "INTERACT"}, "text_refs": {"PMID": "28107481", "TRID": 16352739, "PMCID": "PMC5287475", "DOI": "10.1371/JOURNAL.PPAT.1006100"}, "source_hash": -5857008756386512230}], "id": "a2b3575a-ae54-4a6a-a256-726aefe5a387", "matches_hash": "6100415255007272"}',
#   'stmt_type': 'Complex'},
#  'rel_type': 'indra_rel',
#  'source_id': '13575',
#  'source_ns': 'HGNC',
#  'target_id': '1103',
#  'target_ns': 'HGNC'}

# %%
res = requests.post(
        'https://discovery.indra.bio/api/get_stmts_for_stmt_hashes',
        json={
          "stmt_hashes": [
            "12484535149707124",
          ],
          "evidence_limit": 200
        }
    )

# %%
res.json()
# Out:
# [{'belief': 0.99995,
#   'evidence': [{'annotations': {'agents': {'coords': [[110, 114], [119, 123]]},
#      'found_by': 'binding_of_and'},
#     'context': {'species': {'db_refs': {'TAXONOMY': '9606'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '25603177',
#     'source_api': 'reach',
#     'source_hash': -1268912701169983876,
#     'text': 'BRD2 and BRD4 have been reported to be involved in cell cycle progression, given the evidence that binding of BRD2 and BRD4 to acetylated chromatin persists even during mitosis when chromatin is highly condensed and transcription is interrupted [XREF_BIBR, XREF_BIBR].',
#     'text_refs': {'DOI': '10.3390/IJMS16011928',
#      'PMCID': 'PMC4307342',
#      'PMID': '25603177',
#      'TRID': 461769}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '25603177',
#     'source_api': 'sparser',
#     'source_hash': -431739944072706480,
#     'text': 'BRD2 and BRD4 have been reported to be involved in cell cycle progression, given the evidence that binding of BRD2 and BRD4 to acetylated chromatin persists even during mitosis when chromatin is highly condensed and transcription is interrupted [ xref , xref ].',
#     'text_refs': {'DOI': '10.3390/IJMS16011928',
#      'PMCID': 'PMC4307342',
#      'PMID': '25603177',
#      'TRID': 461769}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '28262505',
#     'source_api': 'sparser',
#     'source_hash': -1362980574378353556,
#     'text': 'As an example, the differential binding of Brd2 and Brd4 in relationship to the enhancer features is illustrated with the ChIP-seq tracks for Il21 and Rock2 , two important genes in Th17 cell differentiation ( xref ).',
#     'text_refs': {'DOI': '10.1016/J.MOLCEL.2016.12.022',
#      'MANUSCRIPT_ID': 'NIHMS843856',
#      'PII': 'S1097-2765(16)30865-6',
#      'PMCID': 'PMC5357147',
#      'PMID': '28262505',
#      'TRID': 17331828}},
#    {'annotations': {'agents': {'coords': [[45, 49], [54, 58]]},
#      'found_by': 'binding7a'},
#     'context': {'cell_type': {'db_refs': {'CL': 'CL:0000899'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '28262505',
#     'source_api': 'reach',
#     'source_hash': -3142412404303348316,
#     'text': 'These results suggested that the kinetics of Brd2 and Brd4 recruitment to their target gene enhancer sites is different, and Brd4 occupancy is likely temporally coupled to the transcriptional activation of these signature genes in Th17 cell differentiation.',
#     'text_refs': {'DOI': '10.1016/J.MOLCEL.2016.12.022',
#      'MANUSCRIPT_ID': 'NIHMS843856',
#      'PII': 'S1097-2765(16)30865-6',
#      'PMCID': 'PMC5357147',
#      'PMID': '28262505',
#      'TRID': 17331828}},
#    {'annotations': {'agents': {'coords': [[151, 155], [156, 160]]},
#      'found_by': 'binding7a'},
#     'context': {'cell_line': {'db_refs': {'CELLOSAURUS': 'CVCL_E031'},
#       'name': None},
#      'cell_type': {'db_refs': {'CL': 'CL:0000899'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '28262505',
#     'source_api': 'reach',
#     'source_hash': 2485932039899088822,
#     'text': 'Notably, the Brd2 and Brd4 co-bound genes exhibit highest expression level, while Brd2 only bound genes show modestly higher expression than genes without Brd2 and Brd4 binding (XREF_FIG).',
#     'text_refs': {'DOI': '10.1016/J.MOLCEL.2016.12.022',
#      'MANUSCRIPT_ID': 'NIHMS843856',
#      'PII': 'S1097-2765(16)30865-6',
#      'PMCID': 'PMC5357147',
#      'PMID': '28262505',
#      'TRID': 17331828}},
#    {'annotations': {'agents': {'coords': [[169, 173], [174, 178]]},
#      'found_by': 'binding7a'},
#     'context': {'cell_line': {'db_refs': {'CELLOSAURUS': 'CVCL_3772'},
#       'name': None},
#      'cell_type': {'db_refs': {'CL': 'CL:0000899'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '28262505',
#     'source_api': 'reach',
#     'source_hash': 6833790319861018728,
#     'text': 'Similarly, peaks bound only by Brd2 are also enriched with Stat3, H3K27Ac and H3K4me1, correlating with the modest increase in gene expression compared to genes without Brd2 and Brd4 binding.',
#     'text_refs': {'DOI': '10.1016/J.MOLCEL.2016.12.022',
#      'MANUSCRIPT_ID': 'NIHMS843856',
#      'PII': 'S1097-2765(16)30865-6',
#      'PMCID': 'PMC5357147',
#      'PMID': '28262505',
#      'TRID': 17331828}},
#    {'annotations': {'agents': {'coords': [[43, 47], [52, 56]]},
#      'found_by': 'binding_of_and'},
#     'context': {'cell_type': {'db_refs': {'CL': 'CL:0000899'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '28262505',
#     'source_api': 'reach',
#     'source_hash': 6687637843694227493,
#     'text': 'As an example, the differential binding of Brd2 and Brd4 in relationship to the enhancer features is illustrated with the ChIP-seq tracks for Il21 and Rock2, two important genes in Th17 cell differentiation (XREF_FIG).',
#     'text_refs': {'DOI': '10.1016/J.MOLCEL.2016.12.022',
#      'MANUSCRIPT_ID': 'NIHMS843856',
#      'PII': 'S1097-2765(16)30865-6',
#      'PMCID': 'PMC5357147',
#      'PMID': '28262505',
#      'TRID': 17331828}},
#    {'annotations': {'found_by': 'BIO-ASSOCIATE'},
#     'pmid': '28666361',
#     'source_api': 'sparser',
#     'source_hash': -6196131680414509189,
#     'text': 'Efforts to directly assess the effect of Hat1 loss on the association of Brd2 and Brd4 with nascent chromatin have been hindered by technical difficulties arising from the effect of the iPOND procedure on the antigenicity of some proteins.',
#     'text_refs': {'DOI': '10.1093/NAR/GKX545',
#      'PMCID': 'PMC5766187',
#      'PMID': '28666361',
#      'TRID': 23428625}},
#    {'annotations': {'found_by': 'BIO-ASSOCIATE'},
#     'pmid': '29448097',
#     'source_api': 'sparser',
#     'source_hash': 1273198415338768569,
#     'text': 'Degradation of BRD2 and BRD4 was associated with significantly reduced expression of several pro-inflammatory genes: inducible nitric oxide synthase (iNOS), cyclooxygenase-2 (COX-2), interleukin (IL)-1β, tumor necrosis factor-a (TNF-α), IL-6, chemokine (C-C motif) ligand 2 (CCL2), and matrix metalloproteinase-9 (MMP-9).',
#     'text_refs': {'DOI': '10.1016/J.BBRC.2018.02.096',
#      'PII': 'S0006-291X(18)30325-5',
#      'PMID': '29448097',
#      'TRID': 28663369}},
#    {'annotations': {'agents': {'coords': [[64, 68], [73, 77]]},
#      'found_by': 'binding_of_and'},
#     'context': {'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '24101376',
#     'source_api': 'reach',
#     'source_hash': -7448167405094626904,
#     'text': 'Thus, BET bromodomain inhibition results in impaired binding of Brd2 and Brd4 to the Il17a gene and its suppressed transcription.',
#     'text_refs': {'DOI': '10.1084/JEM.20130376',
#      'PMCID': 'PMC3804955',
#      'PMID': '24101376',
#      'TRID': 14830058}},
#    {'annotations': {'found_by': 'BIO-ASSOCIATE'},
#     'pmid': '24101376',
#     'source_api': 'sparser',
#     'source_hash': -5030966166575563806,
#     'text': 'After 20 h of culture, both Brd2 and Brd4 significantly associated with chromatin at the Il17a control region CNS2 (essential for Il17a transcription; xref ) in T H 17 but not T H 1 or T H 2 cells, and this binding was prevented by JQ1, significantly for Brd4 ( xref ).',
#     'text_refs': {'DOI': '10.1084/JEM.20130376',
#      'PMCID': 'PMC3804955',
#      'PMID': '24101376',
#      'TRID': 14830058}},
#    {'annotations': {'found_by': 'BIO-ASSOCIATE'},
#     'pmid': '24101376',
#     'source_api': 'sparser',
#     'source_hash': 3348722045115010747,
#     'text': 'JQ1 had no impact on H3K4me3 or acetylation on CNS2 ( xref ), suggesting that the reduced association of Brd2 and Brd4 at this site was not an indirect consequence of altered chromatin structure.',
#     'text_refs': {'DOI': '10.1084/JEM.20130376',
#      'PMCID': 'PMC3804955',
#      'PMID': '24101376',
#      'TRID': 14830058}},
#    {'annotations': {'agents': {'coords': [[148, 152], [157, 161]]},
#      'found_by': 'binding_of_and'},
#     'context': {'cell_line': {'db_refs': {'CELLOSAURUS': 'CVCL_0006'},
#       'name': None},
#      'species': {'db_refs': {'TAXONOMY': '9606'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'hypothesis': True, 'section_type': None},
#     'pmid': '24733848',
#     'source_api': 'reach',
#     'source_hash': -1663058542856109591,
#     'text': 'By coimmunoprecipitation, BET proteins were found to be complexed with Nrf2, whereas chromatin immunoprecipitation studies indicated recruitment of Brd2 and Brd4 to Nrf2 binding sites on the promoters of heme oxygenase-1 and NADPH quinone oxidoreductase 1.',
#     'text_refs': {'DOI': '10.4049/JIMMUNOL.1301984',
#      'MANUSCRIPT_ID': 'EMS57649',
#      'PMCID': 'PMC4011694',
#      'PMID': '24733848',
#      'TRID': 15327612}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '24391744',
#     'source_api': 'sparser',
#     'source_hash': 7932191398242087428,
#     'text': 'RVX-208 binds to BRD4[BD1] and BRD2[BD2] quite differently than does JQ-1, which is based on a triazolodiazepine core scaffold ( xref ).',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PONE.0083190',
#      'PMCID': 'PMC3877016',
#      'PMID': '24391744',
#      'TRID': 12863164}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '24146617',
#     'source_api': 'sparser',
#     'source_hash': -3399788377626380698,
#     'text': 'The only prior evidence for a function of the residues within this patch was the observation that deletion of the last 23 amino acids of LANA abrogates interaction with BRD2 and BRD4.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1003672',
#      'PMCID': 'PMC3798644',
#      'PMID': '24146617',
#      'TRID': 18437976}},
#    {'annotations': {'agents': {'coords': [[32, 36], [55, 59]]},
#      'found_by': 'binding_of_and'},
#     'context': {'species': {'db_refs': {'TAXONOMY': '4932'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '28710461',
#     'source_api': 'reach',
#     'source_hash': 3325422374894809334,
#     'text': 'As expected, the recruitment of BRD4, BRD2 and BRD3 proteins was lost on nSBs in the presence of JQ1, thus validating the efficacy of the JQ1 treatment in stressed cells.',
#     'text_refs': {'DOI': '10.1038/S41598-017-05343-8',
#      'PMCID': 'PMC5511177',
#      'PMID': '28710461',
#      'TRID': 26399022}},
#    {'annotations': {'agents': {'coords': [[12, 16], [21, 25]]},
#      'found_by': 'binding7a'},
#     'context': {'cell_line': {'db_refs': {'CELLOSAURUS': 'CVCL_F568'},
#       'name': None},
#      'species': {'db_refs': {'TAXONOMY': '12305'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '20422051',
#     'source_api': 'reach',
#     'source_hash': -7832113606310167420,
#     'text': 'Analysis of Brd2 and Brd4 recruitment during activation.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PONE.0010272',
#      'PMCID': 'PMC2858074',
#      'PMID': '20422051',
#      'TRID': 6018171}},
#    {'annotations': {'agents': {'coords': [[127, 131], [136, 140]]},
#      'found_by': 'binding_of_and'},
#     'context': {'species': {'db_refs': {'TAXONOMY': '12305'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '20422051',
#     'source_api': 'reach',
#     'source_hash': 1297633045375091280,
#     'text': 'To investigate the timing of the events regulating transcriptional activation, we tracked the recruitment of GCN5, RNA pol II, Brd4 and Brd2 in relation to the VP16 activator, Cherry-tTA-ER.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PONE.0010272',
#      'PMCID': 'PMC2858074',
#      'PMID': '20422051',
#      'TRID': 6018171}},
#    {'annotations': {'agents': {'coords': [[35, 39], [47, 51]]},
#      'found_by': 'binding_of_and'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '31324754',
#     'source_api': 'reach',
#     'source_hash': 6832921576998854502,
#     'text': 'IFN-gamma increased the binding of BRD2, BRD3, BRD4, and Pol II on the IDO1 promoter by increasing the acetylation of histone H3, which could be prevented by JQ1 partially or even completely.',
#     'text_refs': {'DOI': '10.1038/S41419-019-1793-9',
#      'PMCID': 'PMC6642217',
#      'PMID': '31324754',
#      'TRID': 30445486}},
#    {'annotations': {'found_by': 'BIO-ASSOCIATE'},
#     'pmid': '29603290',
#     'source_api': 'sparser',
#     'source_hash': -3681589234244299232,
#     'text': 'Brd2 and Brd4 associate with the IL17 locus in Th17 cells and regulate the expression of cytokines such as IL17, IL21 and GMCSF (Granulocyte-macrophage colony-stimulating factor) in experimental autoimmune encephalitis (EAE), a mouse model for MS[ xref ].',
#     'text_refs': {'DOI': '10.1002/BIES.201800007',
#      'MANUSCRIPT_ID': 'NIHMS1510467',
#      'PMCID': 'PMC7025392',
#      'PMID': '29603290',
#      'TRID': 28436769}},
#    {'annotations': {'agents': {'coords': [[35, 39], [44, 48]]},
#      'found_by': 'binding7a'},
#     'context': {'species': {'db_refs': {'TAXONOMY': '9606'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '32821285',
#     'source_api': 'reach',
#     'source_hash': 2414767758529183005,
#     'text': 'This is likely a direct effect, as BRD2 and BRD4 recruitment to the CRP promoter is detected early on during dual cytokine stimulation (2h), and a short-term treatment with apabetalone or JQ1 (a pan-BETi with a different scaffold) counters the CRP promoter occupancy by BRD4 and the CRP gene induction by cytokines.',
#     'text_refs': {'DOI': '10.1155/2020/9397109',
#      'PMCID': 'PMC7416228',
#      'PMID': '32821285',
#      'TRID': 31998872}},
#    {'annotations': {'found_by': 'BIO-ASSOCIATE'},
#     'pmid': '33105802',
#     'source_api': 'sparser',
#     'source_hash': 8130093037124285424,
#     'text': 'Brd2 and Brd4 physically associate with the promoters of inflammatory cytokine genes, reducing production of cytokines TNFα, IL-6, MCP-1 in vitro and in vivo.',
#     'text_refs': {'DOI': '10.3390/IJMS21217838',
#      'PII': 'E7838',
#      'PMCID': 'PMC7660108',
#      'PMID': '33105802',
#      'TRID': 32300692}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '32723797',
#     'source_api': 'sparser',
#     'source_hash': 1824939100655059296,
#     'text': 'Furthermore, we showed that the E-protein interacts with bromodomain proteins (BRD4), which is in agreement with a previous study in which the researchers showed that SARS-CoV-2 envelop interacted with bromodomain proteins BRD2 and BRD4 to regulate gene transcription ( xref ).',
#     'text_refs': {'DOI': '10.1128/MSYSTEMS.00505-20',
#      'PII': 'E00505-20',
#      'PMCID': 'PMC7394360',
#      'PMID': '32723797',
#      'TRID': 31894111}},
#    {'annotations': {'found_by': 'BIO-COMPLEX'},
#     'pmid': '30080437',
#     'source_api': 'sparser',
#     'source_hash': -1370653684994509689,
#     'text': 'Fernandez-Alonso R, Davidson L, Hukelmann J, et al. Brd4-Brd2 isoform switching coordinates pluripotent exit and Smad2-dependent lineage specification.',
#     'text_refs': {'DOI': '10.1080/15592294.2018.1469891',
#      'PMCID': 'PMC6140815',
#      'PMID': '30080437',
#      'TRID': 29194343}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '31283444',
#     'source_api': 'sparser',
#     'source_hash': -4294641991660342779,
#     'text': 'The Bromodomain and Extra-Terminal Domain proteins Brd2 and Brd4 interact with the electrostatic patch on the LANA DBD ( xref , xref ).',
#     'text_refs': {'DOI': '10.1146/ANNUREV-VIROLOGY-092818-015716',
#      'MANUSCRIPT_ID': 'NIHMS1591078',
#      'PMCID': 'PMC7415349',
#      'PMID': '31283444',
#      'TRID': 30403616}},
#    {'annotations': {'agents': {'coords': [[125, 129], [142, 146]]},
#      'found_by': 'binding1a'},
#     'context': {'cell_type': {'db_refs': {'CL': 'CL:0000235'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '12721'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '24261714',
#     'source_api': 'reach',
#     'source_hash': 4100179229960191050,
#     'text': 'It has recently been demonstrated that BRD2 is essential for proinflammatory cytokine production in macrophagesand that that BRD2, as well as BRD4, physically associates with promoters of inflammatory cytokine genes in macrophages [55].',
#     'text_refs': {'DOI': '10.1517/13543776.2014.859244',
#      'PMID': '24261714',
#      'TRID': 14409995}},
#    {'annotations': {'found_by': 'BINDING'},
#     'source_api': 'sparser',
#     'source_hash': 3231669455480182511,
#     'text': 'Additionally, the ET domains of BRD2 and BRD4 binding on the surface of KSHV LANA (kLANA) are required for the formation of kLANA “nuclear speckles” and latent replication [ xref ].',
#     'text_refs': {'DOI': '10.1186/S13567-020-00846-1',
#      'PMCID': 'PMC7509934',
#      'TRID': 32170661}},
#    {'annotations': {'agents': {'coords': [[189, 193], [198, 202]]},
#      'found_by': 'binding9'},
#     'context': {'species': {'db_refs': {'TAXONOMY': '10116'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '33664670',
#     'source_api': 'reach',
#     'source_hash': 8972124502805479594,
#     'text': 'Since BET proteins can recognize acetylated lysine residues and interact with many chromatin remodeling proteins and some transcriptional factors, it is anticipated that the interaction of Brd2 and Brd4 with transcriptional factors and histone modifiers would initiate a signal that regulates expression of these two BET proteins through a feed-back loop, while inhibition of such interactions may block this process, leading to downregulation of Brd2 and Brd4.',
#     'text_refs': {'DOI': '10.3389/FPHAR.2021.636154',
#      'PMCID': 'PMC7921804',
#      'PMID': '33664670',
#      'TRID': 32889295}},
#    {'annotations': {'agents': {'coords': [[107, 111], [119, 123]]},
#      'found_by': 'binding1a'},
#     'context': {'species': {'db_refs': {'TAXONOMY': '9606'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '33052224',
#     'source_api': 'reach',
#     'source_hash': -8004389247056298804,
#     'text': 'Recently, the tumor promotion functions of bromodomain and extra-terminal domain (BET) proteins, including BRD2, BRD3, BRD4, and BRDT, which bind to acetylated histones, have attracted great attention XREF_BIBR.',
#     'text_refs': {'DOI': '10.7150/THNO.47432',
#      'PMCID': 'PMC7546000',
#      'PMID': '33052224',
#      'TRID': 32242050}},
#    {'annotations': {'found_by': 'BINDING'},
#     'source_api': 'sparser',
#     'source_hash': -4137554909019990108,
#     'text': 'The viral envelope E binds to BRD2 and BRD4 and could be the target for BET inhibitors [39, 45].',
#     'text_refs': {'DOI': '10.1186/S13148-020-00912-7',
#      'PMCID': 'PMC7404079',
#      'TRID': 31930067}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '32353859',
#     'source_api': 'sparser',
#     'source_hash': -558224296440506518,
#     'text': 'We found that the transmembrane E protein, likely resident on ERGIC and golgi membranes, binds to BRD2 and BRD4 ( xref ), members of the bromodomain and extra-terminal (BET) domain family of epigenetic readers that bind acetylated histones to regulate gene transcription  xref  .',
#     'text_refs': {'DOI': '10.1038/S41586-020-2286-9',
#      'MANUSCRIPT_ID': 'NIHMS1587111',
#      'PMCID': 'PMC7431030',
#      'PMID': '32353859',
#      'TRID': 31491138}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '33193257',
#     'source_api': 'sparser',
#     'source_hash': -8051938457108164680,
#     'text': 'In this study we therefore explored (i) if the interaction of kLANA with Brd2 or Brd4 contributes to the previously reported preferential deposition of kLANA on cellular TSS and, (ii) if so, whether this would have an impact on kLANA-mediated transcriptional regulation.',
#     'text_refs': {'DOI': '10.3389/FMICB.2020.591778',
#      'PMCID': 'PMC7642799',
#      'PMID': '33193257',
#      'TRID': 32395435}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '33193257',
#     'source_api': 'sparser',
#     'source_hash': 7020387474289822725,
#     'text': 'Interestingly, treatment with I-BET151 markedly reduced the deposition of kLANA, as well as of Brd4 and Brd2, on cellular TSS, suggesting that the previously reported interaction of kLANA with Brd2 and Brd4 ( xref ; xref ; xref ; xref ) contributes to this characteristic association of kLANA with cellular TSS.',
#     'text_refs': {'DOI': '10.3389/FMICB.2020.591778',
#      'PMCID': 'PMC7642799',
#      'PMID': '33193257',
#      'TRID': 32395435}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '33193257',
#     'source_api': 'sparser',
#     'source_hash': 150519099135702065,
#     'text': 'To extend these observations to the related γ2-herpesvirus MHV-68 and to control for the well-known pleiotropic effects of I-BET151 on cellular gene expression ( xref ; xref ; xref ; xref ), we generated stable A20 murine B cell lines expressing either mLANA WT or mLANA mutant, in which three lysine residues in the basic patch on the surface of the mLANA DNA-binding domain had been mutated to alanine residues and which had lost the ability to interact with Brd2 and Brd4 ( xref ).',
#     'text_refs': {'DOI': '10.3389/FMICB.2020.591778',
#      'PMCID': 'PMC7642799',
#      'PMID': '33193257',
#      'TRID': 32395435}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '33193257',
#     'source_api': 'sparser',
#     'source_hash': 7912407618906750107,
#     'text': 'For mLANA-expressing murine B cells we found more cellular genes to be up- or downregulated compared to cells expressing the mLANA 3A mutant that is deficient in the interaction with Brd2 and Brd4 and which showed a reduced deposition of mLANA on cellular TSS ( xref , xref ); in addition, a significant proportion of mLANA-upregulated or -downregulated cellular genes had TSS that were occupied by mLANA ( xref ).',
#     'text_refs': {'DOI': '10.3389/FMICB.2020.591778',
#      'PMCID': 'PMC7642799',
#      'PMID': '33193257',
#      'TRID': 32395435}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '33193257',
#     'source_api': 'sparser',
#     'source_hash': -4706253506653637174,
#     'text': 'We used conventional ChIP-qPCR on selected cellular promoters of IQGAP3 and TRIM2 to confirm that the binding of kLANA as well as Brd2 and Brd4 was reduced in the presence of I-BET151 ( xref ).',
#     'text_refs': {'DOI': '10.3389/FMICB.2020.591778',
#      'PMCID': 'PMC7642799',
#      'PMID': '33193257',
#      'TRID': 32395435}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '33193257',
#     'source_api': 'sparser',
#     'source_hash': -2104842687209585569,
#     'text': 'We therefore transduced mouse A20 B cells with lentiviral vectors to express a FLAG-tagged mLANA WT or the previously described mLANA 3A mutant (K169A, K224A, and K228A), which is deficient in binding to Brd2 and Brd4 in vitro ( xref ), in a doxycycline-inducible manner ( xref ).',
#     'text_refs': {'DOI': '10.3389/FMICB.2020.591778',
#      'PMCID': 'PMC7642799',
#      'PMID': '33193257',
#      'TRID': 32395435}},
#    {'annotations': {'agents': {'coords': [[145, 149], [154, 158]]},
#      'found_by': 'binding7a'},
#     'context': {'cell_type': {'db_refs': {'CL': 'CL:0000056'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '33257646',
#     'source_api': 'reach',
#     'source_hash': 4638557496233781811,
#     'text': 'BRD4 direct association to chromatin regulatory regions of the NADPH oxidase subunits increases in the mdx muscle and JQ1 administration reduces BRD4 and BRD2 recruitment at these regions.',
#     'text_refs': {'DOI': '10.1038/S41467-020-19839-X',
#      'PMCID': 'PMC7705749',
#      'PMID': '33257646',
#      'TRID': 32462298}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '33490899',
#     'source_api': 'sparser',
#     'source_hash': -8116242832074088240,
#     'text': 'Overall, these findings show that RANKL brings about changes in the BET protein chromatin-binding landscape at the very first stages of OC commitment (4h), chiefly detected as enhanced binding of Brd2 and Brd4, and such changes are exquisitely sensitive to pharmacological inhibition.',
#     'text_refs': {'DOI': '10.1016/J.ISCI.2020.101989',
#      'PMCID': 'PMC7807155',
#      'PMID': '33490899',
#      'TRID': 32703499}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '33490899',
#     'source_api': 'sparser',
#     'source_hash': 4689116051313994738,
#     'text': 'Gain of Brd2 or Brd4 binding occurs with, but mostly without, concurrent Brd4 and Brd2 increased binding, respectively, and in either case, it does not involve changes in Brd3 binding ( xref D–2F).',
#     'text_refs': {'DOI': '10.1016/J.ISCI.2020.101989',
#      'PMCID': 'PMC7807155',
#      'PMID': '33490899',
#      'TRID': 32703499}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '33683199',
#     'source_api': 'sparser',
#     'source_hash': -3394885140870022069,
#     'text': 'However, recent results suggest that the acetyl-histone binding proteins BRD2 and BRD4 physically interact with the rate limiting origin firing factor TICRR/TRESLIN and that abrogation of this interaction disrupts the normal replication program (Sansam et al., 2018).',
#     'text_refs': {'DOI': '10.7554/ELIFE.62161',
#      'PII': 'E62161',
#      'PMCID': 'PMC7993996',
#      'PMID': '33683199',
#      'TRID': 32905265}},
#    {'annotations': {'found_by': 'BIO-FORM'},
#     'pmid': '32895492',
#     'source_api': 'sparser',
#     'source_hash': 3115544355397100819,
#     'text': 'These findings demonstrate that each BET protein forms nuclear condensates in definitive endoderm, and the condensates formed by BRD3 are distinct from those formed by BRD2 and BRD4.',
#     'text_refs': {'DOI': '10.1038/S41556-020-0572-2',
#      'MANUSCRIPT_ID': 'NIHMS1672520',
#      'PMCID': 'PMC8008247',
#      'PMID': '32895492',
#      'TRID': 32075186}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '33717143',
#     'source_api': 'sparser',
#     'source_hash': -5337882370638047056,
#     'text': 'BET Bromodomain Inhibition Reduces Both BRD2 and BRD4 Binding to Promoters.',
#     'text_refs': {'DOI': '10.3389/FIMMU.2021.626255',
#      'PMCID': 'PMC7953504',
#      'PMID': '33717143',
#      'TRID': 32946310}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '32416067',
#     'source_api': 'sparser',
#     'source_hash': 2246333765927942016,
#     'text': 'We found that BRD4, BRD2, and H3K27ac bind to the same promoters and enhancers in both SUM159 and SUM149 cells ( xref and xref ).',
#     'text_refs': {'DOI': '10.1016/J.MOLCEL.2020.04.027',
#      'MANUSCRIPT_ID': 'NIHMS1589967',
#      'PII': 'S1097-2765(20)30269-0',
#      'PMCID': 'PMC7306005',
#      'PMID': '32416067',
#      'TRID': 31548524}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '32416067',
#     'source_api': 'sparser',
#     'source_hash': -3109462049206809725,
#     'text': 'Although both BRD4 and BRD2 binding was decreased after JQ1 treatment ( xref and xref ) and this was highly correlated in both promoter and enhancer regions ( xref and xref ), the decrease was more significant for BRD4 than BRD2.',
#     'text_refs': {'DOI': '10.1016/J.MOLCEL.2020.04.027',
#      'MANUSCRIPT_ID': 'NIHMS1589967',
#      'PII': 'S1097-2765(20)30269-0',
#      'PMCID': 'PMC7306005',
#      'PMID': '32416067',
#      'TRID': 31548524}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '32416067',
#     'source_api': 'sparser',
#     'source_hash': -7372165254709077328,
#     'text': 'We observed an increase of BRD4 and BRD2 binding in the same promoter and enhancer regions in SUM159R cells compared to parental cells ( xref – xref and xref – xref ).',
#     'text_refs': {'DOI': '10.1016/J.MOLCEL.2020.04.027',
#      'MANUSCRIPT_ID': 'NIHMS1589967',
#      'PII': 'S1097-2765(20)30269-0',
#      'PMCID': 'PMC7306005',
#      'PMID': '32416067',
#      'TRID': 31548524}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '33355184',
#     'source_api': 'sparser',
#     'source_hash': -1051051180124805933,
#     'text': 'Previous reports suggest this is through a physical interaction between GBAF-specific subunits and BRD4 [ xref , xref , xref – xref ], and in prostate cancers we find BRD9 interacts with BRD4 as well as BRD2.',
#     'text_refs': {'DOI': '10.1158/0008-5472.CAN-20-1417',
#      'MANUSCRIPT_ID': 'NIHMS1656858',
#      'PII': 'CANRES.1417.2020',
#      'PMCID': 'PMC8026650',
#      'PMID': '33355184',
#      'TRID': 32572620}},
#    {'annotations': {'agents': {'coords': [[30, 34], [39, 43]]},
#      'found_by': 'binding7a'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '34439792',
#     'source_api': 'reach',
#     'source_hash': -8031645727601628275,
#     'text': 'Mutations in mLANA preventing BRD2 and BRD4 binding [158] also have similar consequences [98].',
#     'text_refs': {'DOI': '10.3390/BIOM11081126',
#      'PII': '1126',
#      'PMCID': 'PMC8391731',
#      'PMID': '34439792',
#      'TRID': 33700101}},
#    {'annotations': {'agents': {'coords': [[61, 65], [66, 70]]},
#      'found_by': 'binding11'},
#     'context': {'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '31527644',
#     'source_api': 'reach',
#     'source_hash': 6152522433921835495,
#     'text': 'JQ1 treatment did not affect the interactions between AR and BRD2/BRD4 (Fig.\xa04A).',
#     'text_refs': {'DOI': '10.1038/S41598-019-49366-9',
#      'PMCID': 'PMC6746817',
#      'PMID': '31527644',
#      'TRID': 30647781}},
#    {'annotations': {'found_by': 'BIO-ASSOCIATE'},
#     'pmid': '31504794',
#     'source_api': 'sparser',
#     'source_hash': -5286486223992926357,
#     'text': 'Although LYAR-UBF could associate with BRD2 or BRD4 even at basal cellular levels (Figure xref ), LYAR-SPT5 did not associate with BRD2 or BRD4 at all (Figure xref ).',
#     'text_refs': {'DOI': '10.1093/NAR/GKZ747',
#      'PII': 'GKZ747',
#      'PMCID': 'PMC6821171',
#      'PMID': '31504794',
#      'TRID': 30622442}},
#    {'annotations': {'found_by': 'BIO-COMPLEX'},
#     'pmid': '31504794',
#     'source_api': 'sparser',
#     'source_hash': -7062373494007330051,
#     'text': 'Collectively, these data support the previous notice that LYAR forms a complex with BRD2 or BRD4, after which either complex can be recruited to rDNA via UBF.',
#     'text_refs': {'DOI': '10.1093/NAR/GKZ747',
#      'PII': 'GKZ747',
#      'PMCID': 'PMC6821171',
#      'PMID': '31504794',
#      'TRID': 30622442}},
#    {'annotations': {'found_by': 'BIO-COMPLEX'},
#     'pmid': '34199719',
#     'source_api': 'sparser',
#     'source_hash': 1005713163275066452,
#     'text': 'In Th17 immune cells, BRD2 interacts with the chromatin insulator CTCF to facilitate SE formation, BRD4 recruitment and gene expression changes via direct BRD2-BRD4 interaction [ xref ].',
#     'text_refs': {'DOI': '10.3390/IJMS22116059',
#      'PII': '6059',
#      'PMCID': 'PMC8199980',
#      'PMID': '34199719',
#      'TRID': 33455506}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '32151278',
#     'source_api': 'sparser',
#     'source_hash': -1649528349232352660,
#     'text': 'Interestingly, the BRG1 component of the SWI/SNF complex which is present in the MITF interactome is also known to physically interact with BRD4 and BRD2 [ xref , xref ].',
#     'text_refs': {'DOI': '10.1186/S13072-020-00333-Z',
#      'PMCID': 'PMC7063807',
#      'PMID': '32151278',
#      'TRID': 31265403}},
#    {'annotations': {'found_by': 'BIO-COMPLEX'},
#     'pmid': '36188615',
#     'source_api': 'sparser',
#     'source_hash': -2015585232763465486,
#     'text': 'In recent years, BET family-targeting small molecules (BRD2–BRD4 and testis-specific BRDT) are novel epi-drugs.',
#     'text_refs': {'DOI': '10.3389/FPHAR.2022.946811',
#      'PMCID': 'PMC9522521',
#      'PMID': '36188615',
#      'TRID': 35557210}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '36187481',
#     'source_api': 'sparser',
#     'source_hash': -6177395182117242136,
#     'text': 'In 2013, Picaud et al. found that PFI-1 inhibitors were acetyl lysine mimics and could replace acetyl lysine to bind to BRD2 and BRD4, thereby inhibiting the recruitment of BET protein to chromatin, down-regulating the expression of MYC and Aurora B kinases ( xref ).',
#     'text_refs': {'DOI': '10.3389/FCELL.2022.1021820',
#      'PMCID': 'PMC9523081',
#      'PMID': '36187481',
#      'TRID': 35553948}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '32946883',
#     'source_api': 'sparser',
#     'source_hash': 1488006042622618533,
#     'text': 'In the 6-OHDA rodent model of levodopa-induced dyskinesia, an animal model for Parkinson’s disease, increased levels of Brd2 mRNA were observed in the dorsal striatum, along with increased binding of BRD2 and BRD4 proteins to the promoter and enhancer regions of the genes dysregulated during dyskinesia induction (e.g., Dab1 , Esr1 , Ntrk2 , Arc , FosB , and Nedd41 ).',
#     'text_refs': {'DOI': '10.1016/J.NEUROPHARM.2020.108306',
#      'MANUSCRIPT_ID': 'NIHMS1633343',
#      'PII': 'S0028-3908(20)30374-9',
#      'PMCID': 'PMC7655633',
#      'PMID': '32946883',
#      'TRID': 32128409}},
#    {'annotations': {'agents': {'coords': [[14, 18], [23, 27]]},
#      'found_by': 'binding7a'},
#     'context': {'cell_line': {'db_refs': {'CELLOSAURUS': 'CVCL_5423'},
#       'name': None},
#      'cell_type': {'db_refs': {'CL': 'CL:0000988'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '9606'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '32416067',
#     'source_api': 'reach',
#     'source_hash': 1015099416024236278,
#     'text': 'Although both BRD4 and BRD2 binding was decreased after JQ1 treatment (Figures 5B and S5B) and this was highly correlated in both promoter and enhancer regions (Figures 5C and S5C), the decrease was more significant for BRD4 than BRD2.',
#     'text_refs': {'DOI': '10.1016/J.MOLCEL.2020.04.027',
#      'MANUSCRIPT_ID': 'NIHMS1589967',
#      'PII': 'S1097-2765(20)30269-0',
#      'PMCID': 'PMC7306005',
#      'PMID': '32416067',
#      'TRID': 31548524}},
#    {'annotations': {'agents': {'coords': [[27, 31], [36, 40]]},
#      'found_by': 'binding7a'},
#     'context': {'cell_line': {'db_refs': {'CELLOSAURUS': 'CVCL_5423'},
#       'name': None},
#      'cell_type': {'db_refs': {'CL': 'CL:0000988'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '9606'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '32416067',
#     'source_api': 'reach',
#     'source_hash': 5870830065324646975,
#     'text': 'We observed an increase of BRD4 and BRD2 binding in the same promoter and enhancer regions in SUM159R cells compared to parental cells (Figures 5B–C and S7B–C).',
#     'text_refs': {'DOI': '10.1016/J.MOLCEL.2020.04.027',
#      'MANUSCRIPT_ID': 'NIHMS1589967',
#      'PII': 'S1097-2765(20)30269-0',
#      'PMCID': 'PMC7306005',
#      'PMID': '32416067',
#      'TRID': 31548524}},
#    {'annotations': {'agents': {'coords': [[69, 73], [84, 88]]},
#      'found_by': 'binding_of_and'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '31504794',
#     'source_api': 'reach',
#     'source_hash': 5195737208917340567,
#     'text': 'Collectively, these data suggested that LYAR-mediated recruitment of BRD2, KAT7 and BRD4 to rDNA controls the acetylation of local histones H3 and H4 to cause the relaxation of these histones from rDNA loci and thereby promote rDNA transcription.',
#     'text_refs': {'DOI': '10.1093/NAR/GKZ747',
#      'PII': 'GKZ747',
#      'PMCID': 'PMC6821171',
#      'PMID': '31504794',
#      'TRID': 30622442}},
#    {'annotations': {'agents': {'coords': [[127, 131], [136, 140]]},
#      'found_by': 'binding1forms'},
#     'context': {'species': {'db_refs': {'TAXONOMY': '9606'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '31504794',
#     'source_api': 'reach',
#     'source_hash': 5055445929519836335,
#     'text': 'Conversely, a pulldown assay using BRD2 or BRD4 as bait showed that neither protein could associate with SPT5 or UBF; however, BRD2 and BRD4—independently of each other—could form a complex containing both LYAR and KAT7-JADE3 (Figure 7C).',
#     'text_refs': {'DOI': '10.1093/NAR/GKZ747',
#      'PII': 'GKZ747',
#      'PMCID': 'PMC6821171',
#      'PMID': '31504794',
#      'TRID': 30622442}},
#    {'annotations': {'agents': {'coords': [[76, 80], [85, 89]]},
#      'found_by': 'binding7a'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '32151278',
#     'source_api': 'reach',
#     'source_hash': -3889510220238043202,
#     'text': 'Therefore, BRG1 or a BRG1-associated factor (BAF) could potentially mediate BRD4 and BRD2 interactions with MITF.',
#     'text_refs': {'DOI': '10.1186/S13072-020-00333-Z',
#      'PMCID': 'PMC7063807',
#      'PMID': '32151278',
#      'TRID': 31265403}},
#    {'annotations': {'agents': {'coords': [[69, 73], [78, 82]]},
#      'found_by': 'binding7a'},
#     'context': {'species': {'db_refs': {'TAXONOMY': '9606'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '34614283',
#     'source_api': 'reach',
#     'source_hash': -2319773555182221260,
#     'text': 'We found this “linker\neffect” even more pronounced in the context of BRD2 and BRD4 binding.',
#     'text_refs': {'DOI': '10.1002/ANIE.202108848',
#      'MANUSCRIPT_ID': 'NIHMS1746931',
#      'PMCID': 'PMC8648984',
#      'PMID': '34614283',
#      'TRID': 33903018}},
#    {'annotations': {'found_by': 'BIO-ASSOCIATE'},
#     'pmid': '30845782',
#     'source_api': 'sparser',
#     'source_hash': -8250698883435670045,
#     'text': 'A short motif in the large C-terminus mediates the binding of Treslin/TICRR Sld3 to the BRD2 and BRD4 proteins that associate with acetylated chromatin via bromodomains.',
#     'text_refs': {'DOI': '10.3390/GENES10030199',
#      'PII': 'E199',
#      'PMCID': 'PMC6470937',
#      'PMID': '30845782',
#      'TRID': 30006704}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '36252792',
#     'source_api': 'sparser',
#     'source_hash': -7129274209896767760,
#     'text': 'The SARS-CoV-2 E protein has been shown to interact with BRD4 and BRD2.',
#     'text_refs': {'DOI': '10.1016/J.CELLSIG.2022.110495',
#      'PII': 'S0898-6568(22)00257-1',
#      'PMCID': 'PMC9568271',
#      'PMID': '36252792',
#      'TRID': 35622609}},
#    {'annotations': {'agents': {'coords': [[77, 81], [83, 87]]},
#      'found_by': 'binding7a'},
#     'context': {'cell_type': {'db_refs': {'CL': 'CL:0002322'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '35410381',
#     'source_api': 'reach',
#     'source_hash': -7615547179400382531,
#     'text': 'Finally, we found that BRD3 depletion did not appear to significantly impact BRD2, BRD4 or CTCF binding to chromatin (Extended Data Fig.10b), possibly due to the fact that BRD3 is expressed at significantly lower levels than BRD2 and BRD4 in ESCs (Fig.4i).',
#     'text_refs': {'DOI': '10.1038/S41588-022-01044-9',
#      'MANUSCRIPT_ID': 'HHMIMS1798525',
#      'PMCID': 'PMC9099420',
#      'PMID': '35410381',
#      'TRID': 34783711}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '34614283',
#     'source_api': 'sparser',
#     'source_hash': -1574796997179142856,
#     'text': 'A similar increase in the CRBN affinity of dBET1 compared\nto thalidomide has been recently reported by others.[ xref ]We found this “linker\neffect” even more pronounced in the context of BRD2 and BRD4 binding.',
#     'text_refs': {'DOI': '10.1002/ANIE.202108848',
#      'MANUSCRIPT_ID': 'NIHMS1746931',
#      'PMCID': 'PMC8648984',
#      'PMID': '34614283',
#      'TRID': 33903018}},
#    {'annotations': {'agents': {'coords': [[0, 4], [20, 24]]},
#      'found_by': 'binding1forms'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '36793283',
#     'source_api': 'reach',
#     'source_hash': -9198286567794486302,
#     'text': 'BRD2 ,  BRD3 , and  BRD4  and their neighboring genes form a complex network of interactions mainly through co-expression, physical interactions, and shared protein domains.',
#     'text_refs': {'DOI': '10.3389/FENDO.2023.1089531',
#      'PMCID': 'PMC9922706',
#      'PMID': '36793283',
#      'TRID': 36236955}},
#    {'annotations': {'agents': {'coords': [[187, 191], [196, 200]]},
#      'found_by': 'binding7a'},
#     'context': {'cell_type': {'db_refs': {'CL': 'CL:0000785'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '26654227',
#     'source_api': 'reach',
#     'source_hash': -8794736254219396140,
#     'text': 'I-BET151, another novel highly selective inhibitor of both BRD2 and BRD4 causes transcriptional silencing of the c-MYC gene and c-MYC-dependent programs in myeloma cells by inhibition of BRD2 and BRD4 binding to the promoter of the c-MYC gene and failure to recruit P-TEFb and PAFc1 complexes to the IGH and c-MYC enhancer by BRD2 and BRD4, and lack of subsequent RNA-Pol-II recruitment [XREF_BIBR].',
#     'text_refs': {'DOI': '10.1186/S12943-015-0474-2',
#      'PMCID': 'PMC4676894',
#      'PMID': '26654227',
#      'TRID': 18648644}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '24954007',
#     'source_api': 'sparser',
#     'source_hash': -4366907290921538505,
#     'text': 'Notably, Olinone showed modest binding to the bromodomains from CBP and PHIP withK d of 33 μM and 103.4 μM, respectively, very weak binding to BRD4-BrD2 withK d >300 μM, and almost no detectable binding to the bromodomains from many other proteins including BRD7, PCAF, ASH1L, TAF1L, SMARCA4, BAZ1B, BAZ2B, ATAD2, BPTF and TRIM24 that represent different subgroups of the human bromodomain family ( xref and xref ).',
#     'text_refs': {'DOI': '10.1016/J.CHEMBIOL.2014.05.009',
#      'MANUSCRIPT_ID': 'NIHMS602357',
#      'PMCID': 'PMC4104156',
#      'PMID': '24954007',
#      'TRID': 4631772}},
#    {'annotations': {'agents': {'coords': [[22, 26], [31, 35]]},
#      'found_by': 'binding1a'},
#     'context': {'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '25606026',
#     'source_api': 'reach',
#     'source_hash': 952004556399021338,
#     'text': 'BRD proteins, such as Brd2 and Brd4, which bind acetylated residues on histones and transcription factors, are important regulators of transcriptional elongation of a subset of inflammatory genes with paused polymerase II [XREF_BIBR].',
#     'text_refs': {'DOI': '10.1186/S12950-014-0043-2',
#      'PMCID': 'PMC4299484',
#      'PMID': '25606026',
#      'TRID': 461366}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '28949335',
#     'source_api': 'sparser',
#     'source_hash': 3823531228494025132,
#     'text': 'The Bromodomain Extraterminal (BET) subfamily of chromatin readers is highly specific toward acetylated histone tails, with highest affinity for H4K12, and H4K5. xref , xref This is interesting, as BRD2 and BRD4 preferentially bind H4K12ac. xref , xref Moreover, H4K5ac and H4K12ac were specifically linked to memory function and age-associated memory impairment. xref , xref , xref ',
#     'text_refs': {'DOI': '10.1038/TP.2017.202',
#      'PMCID': 'PMC5639246',
#      'PMID': '28949335',
#      'TRID': 7437585}},
#    {'annotations': {'found_by': 'BIO-ASSOCIATE'},
#     'pmid': '18406326',
#     'source_api': 'sparser',
#     'source_hash': 6834652193375750423,
#     'text': 'The Brd2 and Brd4 proteins associate primarily with euchromatic regions of the genome, and are largely excluded from heterochromatin, suggesting that these proteins might regulate transcription ( Crowley et\xa0al., 2002; Dey et\xa0al., 2000, 2003; Mattsson et\xa0al., 2002 ).',
#     'text_refs': {'DOI': '10.1016/J.MOLCEL.2008.01.018',
#      'PMCID': 'PMC2387119',
#      'PMID': '18406326',
#      'TRID': 27222031}},
#    {'annotations': {'author': 'Rahman S (2011)',
#      'biogrid_a': '117036',
#      'biogrid_b': '111973',
#      'biogrid_int_id': '612035',
#      'entrez_a': '23476',
#      'entrez_b': '6046',
#      'exp_system': 'Affinity Capture-MS',
#      'exp_system_type': 'physical',
#      'hgnc_a': 'BRD4',
#      'hgnc_b': 'BRD2',
#      'modification': None,
#      'organism_a': '9606',
#      'organism_b': '9606',
#      'phenotypes': None,
#      'pmid': '21555454',
#      'qualifications': None,
#      'score': None,
#      'source_db': 'BIOGRID',
#      'syn_a': 'CAP|HUNK1|HUNKI|MCAP',
#      'syn_b': 'D6S113E|FSH|FSRG1|NAT|RING3|RNF3',
#      'syst_name_a': None,
#      'syst_name_b': 'DADB-17J1.3',
#      'tags': None,
#      'throughput': 'High Throughput'},
#     'pmid': '21555454',
#     'source_api': 'biogrid',
#     'source_hash': 4060451246017069409,
#     'source_id': '612035',
#     'text_refs': {'PMID': '21555454'}},
#    {'annotations': {'found_by': 'BIO-ASSOCIATE'},
#     'pmid': '31126889',
#     'source_api': 'sparser',
#     'source_hash': -7452390478202661618,
#     'text': 'Mechanistically, ChIP assays demonstrated that JQ1 decreased the association of BRD4 and BRD2 with promoter loci of Ku80 and RAD51, and shRNA data showed that expression of Ku80 and RAD51 was BRD4- and BRD2-dependent in PDAC cell lines.',
#     'text_refs': {'DOI': '10.1016/J.EBIOM.2019.05.035',
#      'PII': 'S2352-3964(19)30343-3',
#      'PMCID': 'PMC6604668',
#      'PMID': '31126889',
#      'TRID': 30243534}},
#    {'annotations': {'agents': {'coords': [[122, 126], [138, 142]]},
#      'found_by': 'binding1a'},
#     'context': {'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '28388437',
#     'source_api': 'reach',
#     'source_hash': 2650534930676615631,
#     'text': 'Consistent with previous reports, we also noted some places, such as the alpha-globin genes (Hba), at which BRD2, BRD3, and BRD4 were all bound (XREF_FIG).',
#     'text_refs': {'DOI': '10.1016/J.MOLCEL.2017.02.027',
#      'MANUSCRIPT_ID': 'NIHMS858015',
#      'PII': 'S1097-2765(17)30164-8',
#      'PMCID': 'PMC5393350',
#      'PMID': '28388437',
#      'TRID': 8522688}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '19736624',
#     'source_api': 'sparser',
#     'source_hash': -4345452178509464260,
#     'text': 'Additionally, both BRD4 and BRD2 interact with the murine γ-herpesvirus 68 protein or f73, which is required to establish viral latency in vivo [ xref ].',
#     'text_refs': {'MANUSCRIPT_ID': 'NIHMS224823',
#      'PMCID': 'PMC2921942',
#      'PMID': '19736624',
#      'TRID': 11175778}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '28176838',
#     'source_api': 'sparser',
#     'source_hash': -1087395168170410616,
#     'text': 'DMA inhibits the binding activity of BRD2 and BRD4 ( xref ) with an IC50 value of 11\u2009mM and 6\u2009mM, respectively ( xref ).',
#     'text_refs': {'DOI': '10.1038/SREP42108',
#      'PMCID': 'PMC5296751',
#      'PMID': '28176838',
#      'TRID': 2658089}},
#    {'annotations': {'agents': {'coords': [[82, 86], [97, 101]]},
#      'found_by': 'binding7a'},
#     'context': {'cell_line': {'db_refs': {'CELLOSAURUS': 'CVCL_0042'},
#       'name': None},
#      'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'hypothesis': True, 'section_type': None},
#     'pmid': '23826629',
#     'source_api': 'reach',
#     'source_hash': 5234946537651563510,
#     'text': 'Enrichment for specific acetylated patterns may have interesting implications for Brd2, Brd3 and Brd4 recruitment, as discussed later.',
# ...
#     'text_refs': {'DOI': '10.1016/J.NBD.2017.03.003',
#      'MANUSCRIPT_ID': 'NIHMS861546',
#      'PII': 'S0969-9961(17)30050-5',
#      'PMCID': 'PMC5410664',
#      'PMID': '28286180',
#      'TRID': 17321672}},
#    {'annotations': {'found_by': 'BIO-ASSOCIATE'},
#     'pmid': '28286180',
#     'source_api': 'sparser',
#     'source_hash': 2226218782658567623,
#     'text': 'Similarly, predicted enhancer regions of Arc , FosB, and Nedd4l also showed increases in the association of Brd2 and Brd4 following repeated L-DOPA administration ( xref , Unpaired t-test, Arc: p = 0.038; FosB: p = 0.002; Nedd4l: p = 0.002) ( xref , Arc: p = 0.022; FosB: p = 0.001; Nedd4l: p = 0.008).',
#     'text_refs': {'DOI': '10.1016/J.NBD.2017.03.003',
#      'MANUSCRIPT_ID': 'NIHMS861546',
#      'PII': 'S0969-9961(17)30050-5',
#      'PMCID': 'PMC5410664',
#      'PMID': '28286180',
#      'TRID': 17321672}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '28286180',
#     'source_api': 'sparser',
#     'source_hash': -3890209657830921265,
#     'text': 'We observed an enhancement in the transcriptional expression of Brd2 following the development of dyskinetic behaviors that correlated with increases in locus-specific Brd2 and Brd4 binding in the dorsal striatum.',
#     'text_refs': {'DOI': '10.1016/J.NBD.2017.03.003',
#      'MANUSCRIPT_ID': 'NIHMS861546',
#      'PII': 'S0969-9961(17)30050-5',
#      'PMCID': 'PMC5410664',
#      'PMID': '28286180',
#      'TRID': 17321672}},
#    {'annotations': {'agents': {'coords': [[118, 122], [127, 131]]},
#      'found_by': 'binding_of_and'},
#     'context': {'cell_type': {'db_refs': {'CL': 'CL:0009002'}, 'name': None},
#      'location': {'db_refs': {'GO': 'GO:0018995'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '29167426',
#     'source_api': 'reach',
#     'source_hash': -6206896914022644068,
#     'text': 'We revealed a direct role for BET proteins both in skeletal muscle and in the tumor, by showing direct recruitment of BRD4 and BRD2 at a subset of pro atrophic genes and pro cachectic mediators.',
#     'text_refs': {'DOI': '10.1038/S41467-017-01645-7',
#      'PMCID': 'PMC5700099',
#      'PMID': '29167426',
#      'TRID': 3293711}},
#    {'annotations': {'agents': {'coords': [[216, 220], [225, 229]]},
#      'found_by': 'binding7a'},
#     'context': {'cell_type': {'db_refs': {'CL': 'CL:0000765'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '27827996',
#     'source_api': 'reach',
#     'source_hash': -3373913262071139406,
#     'text': 'An increase in BRD3 occupancy at GATA1 sites following GATA1 activation is most significant as compared to that of BRD2 and BRD4 occupancy, suggesting that BRD3 recruitment is predominantly affected by GATA1 whereas BRD2 and BRD4 recruitment is regulated by factors besides GATA1 [XREF_BIBR].',
#     'text_refs': {'DOI': '10.3390/IJMS17111849',
#      'PII': 'E1849',
#      'PMCID': 'PMC5133849',
#      'PMID': '27827996',
#      'TRID': 16545836}},
#    {'annotations': {'agents': {'coords': [[31, 35], [47, 51]]},
#      'found_by': 'binding1a'},
#     'context': {'species': {'db_refs': {'TAXONOMY': '10090'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '29343972',
#     'source_api': 'reach',
#     'source_hash': -1489016897268575299,
#     'text': 'Particularly, the BET proteins BRD2, BRD3, and BRD4 recognize and bind to the acetylated histone-lysine residues.',
#     'text_refs': {'DOI': '10.2147/OTT.S145971',
#      'PMCID': 'PMC5749389',
#      'PMID': '29343972',
#      'TRID': 28174205}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '27827996',
#     'source_api': 'sparser',
#     'source_hash': 1256873096803204907,
#     'text': 'BRD2 and BRD4 Interact with Viral Proteins and Contribute to Oncogenesis in Host Cells Infected with Viruses.',
#     'text_refs': {'DOI': '10.3390/IJMS17111849',
#      'PII': 'E1849',
#      'PMCID': 'PMC5133849',
#      'PMID': '27827996',
#      'TRID': 16545836}},
#    {'annotations': {'agents': {'coords': [[39, 43], [47, 51]]},
#      'found_by': 'binding9'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '28107481',
#     'source_api': 'reach',
#     'source_hash': -5637226443740668066,
#     'text': 'JQ1 did not disrupt the interaction of BRD4 or BRD2 with LANA, but did reduce the binding of LANA with KSHV TR.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'agents': {'coords': [[31, 35], [40, 44]]},
#      'found_by': 'binding7a'},
#     'context': {'cell_line': {'db_refs': {'CELLOSAURUS': 'CVCL_9T72'},
#       'name': None},
#      'species': {'db_refs': {'TAXONOMY': '12721'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '28107481',
#     'source_api': 'reach',
#     'source_hash': 6328739575729990928,
#     'text': 'JQ1 is known to act rapidly on BRD2 and BRD4 binding to acetylated histones [XREF_BIBR], but its kinetic effects on transcription can be complex.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'agents': {'coords': [[29, 33], [37, 41]]},
#      'found_by': 'binding7a'},
#     'context': {'location': {'db_refs': {'GO': 'GO:0019015'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '12721'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '28107481',
#     'source_api': 'reach',
#     'source_hash': -4460096269124692310,
#     'text': 'To determine if JQ1 affected BRD4 or BRD2 interaction with LANA, we assayed the effects of JQ1 on the coimmunoprecipitation (coIP) of LANA with BRD4 (XREF_FIG, top panels) or with BRD2 (XREF_FIG, lower panels).',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'agents': {'coords': [[36, 40], [45, 49]]},
#      'found_by': 'binding7a'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '28107481',
#     'source_api': 'reach',
#     'source_hash': 1233503277108519757,
#     'text': 'We found that JQ1 treatment reduced BRD2 and BRD4 interactions at the TR regions by ~ 50% (XREF_FIG).',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'agents': {'coords': [[109, 113], [117, 121]]},
#      'found_by': 'binding9'},
#     'context': {'location': {'db_refs': {'GO': 'GO:0005694'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '12721'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '28107481',
#     'source_api': 'reach',
#     'source_hash': -5124102464736639245,
#     'text': 'JQ1 reduced binding of LANA to the TR and latency control region, but did not destabilize the interaction of BRD4 or BRD2 with LANA protein.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'agents': {'coords': [[46, 50], [52, 56]]},
#      'found_by': 'binding7a'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '28107481',
#     'source_api': 'reach',
#     'source_hash': -7561618092911824593,
#     'text': 'However, our finding that JQ1 rapidly reduces BRD2, BRD4, LANA and RAD21 interaction with KSHV genomes, and alters KSHV chromatin conformation independently of viral DNA replication, suggest that JQ1 can also act directly on the KSHV epigenome.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'agents': {'coords': [[18, 22], [27, 31]]},
#      'found_by': 'binding7a'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '28107481',
#     'source_api': 'reach',
#     'source_hash': -1726249009983314939,
#     'text': 'JQ1 disruption of BRD2 and BRD4 interaction with chromatin is known to occur at very early times, but how these early events regulate subsequent transcriptional and conformational events are not known.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'agents': {'coords': [[41, 45], [50, 54]]},
#      'found_by': 'binding7a'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '28107481',
#     'source_api': 'reach',
#     'source_hash': 7926294519403353828,
#     'text': 'We suggest that JQ1 direct disruption of BRD2 and BRD4 interaction with KSHV chromatin leads to several subsequent events, including the loss of LANA binding to TR, loss of RAD21 dependent conformational control, and transcriptional derepression of KSHV lytic immediate early genes.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'agents': {'coords': [[79, 83], [87, 91]]},
#      'found_by': 'binding11'},
#     'context': {'location': {'db_refs': {'GO': 'GO:0019015'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '12721'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'hypothesis': True, 'section_type': None},
#     'pmid': '28107481',
#     'source_api': 'reach',
#     'source_hash': 8745564572145391722,
#     'text': 'However, we were unable to demonstrate any direct physical interaction between BRD2 or BRD4 with cohesin subunit RAD21 (XREF_SUPPLEMENTARY), suggesting the conformational control of KSHV latency involves additional factors.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'found_by': 'BIO-ASSOCIATE'},
#     'pmid': '28107481',
#     'source_api': 'sparser',
#     'source_hash': 2540504005750765779,
#     'text': 'We found that BRD2 and BRD4 associated with all three viral genome positions, showing the highest enrichment at the LANA binding sites at the TR.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '28107481',
#     'source_api': 'sparser',
#     'source_hash': -8275654358246284226,
#     'text': 'Neither BRD2 nor BRD4 bound to a region within the ORF37 gene (primer i), indicating that the enrichment at control regulatory regions is selective.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '28107481',
#     'source_api': 'sparser',
#     'source_hash': 3887134724099467843,
#     'text': 'We next asked whether JQ1 had any effect on the binding of BRD4 or BRD2 proteins to KSHV genome by ChIP assay ( xref ).',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '28107481',
#     'source_api': 'sparser',
#     'source_hash': -7506324149212461697,
#     'text': 'We found that JQ1 treatment reduced BRD2 and BRD4 interactions at the TR regions by ~50% ( xref ).',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '28107481',
#     'source_api': 'sparser',
#     'source_hash': 8087079647002684130,
#     'text': 'These findings indicate that BRD2 and BRD4 can interact with viral regulatory regions, and that JQ1 can partially disrupt these interactions.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '28107481',
#     'source_api': 'sparser',
#     'source_hash': -1153727522038570162,
#     'text': 'JQ1 disruption of BRD2 and BRD4 interaction with chromatin is known to occur at very early times, but how these early events regulate subsequent transcriptional and conformational events are not known.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'found_by': 'INTERACT'},
#     'pmid': '28107481',
#     'source_api': 'sparser',
#     'source_hash': -531056453524432072,
#     'text': 'We suggest that JQ1 direct disruption of BRD2 and BRD4 interaction with KSHV chromatin leads to several subsequent events, including the loss of LANA binding to TR, loss of RAD21-dependent conformational control, and transcriptional derepression of KSHV lytic immediate early genes.',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'found_by': 'BINDING'},
#     'pmid': '28107481',
#     'source_api': 'sparser',
#     'source_hash': -1448027423943845655,
#     'text': 'LANA is known to bind to BRD2 [ xref ] and BRD4 [ xref , xref ], and biophysical analyses revealed a direct interaction with the LANA DNA binding domain [ xref ].',
#     'text_refs': {'DOI': '10.1371/JOURNAL.PPAT.1006100',
#      'PMCID': 'PMC5287475',
#      'PMID': '28107481',
#      'TRID': 16352739}},
#    {'annotations': {'agents': {'coords': [[30, 34], [39, 43]]},
#      'found_by': 'binding1a'},
#     'context': {'location': {'db_refs': {'GO': 'GO:0005694'}, 'name': None},
#      'species': {'db_refs': {'TAXONOMY': '9606'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '20709061',
#     'source_api': 'reach',
#     'source_hash': -6658758430223294719,
#     'text': 'Importantly, the BET proteins BRD2 and BRD4 associate with acetylated chromatin throughout the cell cycle [XREF_BIBR, XREF_BIBR], while other non BET bromodomain family members dissociate from the chromosomes during mitosis [XREF_BIBR].',
#     'text_refs': {'DOI': '10.1016/J.FEBSLET.2010.08.013',
#      'MANUSCRIPT_ID': 'NIHMS618856',
#      'PMCID': 'PMC4158924',
#      'PMID': '20709061',
#      'TRID': 1837339}},
#    {'annotations': {'agents': {'coords': [[82, 86], [94, 98]]},
#      'found_by': 'binding_of_and'},
#     'context': {'species': {'db_refs': {'TAXONOMY': '9606'}, 'name': None},
#      'type': 'bio'},
#     'epistemics': {'direct': True, 'section_type': None},
#     'pmid': '23604113',
#     'source_api': 'reach',
#     'source_hash': 448900016323780311,
#     'text': 'JQ1 is not specific for BRD-NUT, as it also competitively inhibits the binding of BRD2, BRD3, BRD4, and BRDT to chromatin, and NMC cells always have at least one intact BRD4 locus and express normal BRD4 as well as BRD-NUT oncoproteins; hence, the observed effects of JQ1 could stem from effects on BRD4, BRD-NUT, or both.',
#     'text_refs': {'DOI': '10.1038/ONC.2013.126',
#      'MANUSCRIPT_ID': 'NIHMS557273',
#      'PMCID': 'PMC3942361',
#      'PMID': '23604113',
#      'TRID': 14226131}}],
#   'id': 'fcf70adf-dc61-4999-b1ee-e17cbe0afb2b',
#   'matches_hash': '12484535149707124',
#   'members': [{'db_refs': {'EGID': '6046',
#      'HGNC': '1103',
#      'TEXT': 'BRD2',
#      'UP': 'P25440'},
#     'name': 'BRD2'},
#    {'db_refs': {'EGID': '23476',
#      'HGNC': '13575',
#      'TEXT': 'BRD4',
#      'UP': 'O60885'},
#     'name': 'BRD4'}],
#   'type': 'Complex'}]

# %%
len(subnetwork_relations)
# Out:
# 140

# %% [markdown]
# ## STEP 4: ASSEMBLE DATA

# %% [markdown]
# INDRA has a set of assembler classes to display the data for further analysis.  Below are some examples of assemblers

# %% [markdown]
# ### HTML Assembler

# %%
import json
from indra.statements import stmts_from_json

# Gather statistics for HTML presentation
unique_stmts = {entry['data']['stmt_hash']: json.loads(entry['data']['stmt_json'])
                for entry in subnetwork_relations}
ev_counts_by_hash = {entry['data']['stmt_hash']: entry['data']['evidence_count']
                     for entry in subnetwork_relations}
source_counts_by_hash = {entry['data']['stmt_hash']: json.loads(entry['data']['source_counts'])
                         for entry in subnetwork_relations}
stmts = stmts_from_json(list(unique_stmts.values()))

# %%
from indra.assemblers.html import HtmlAssembler
ha = HtmlAssembler(stmts,
                   title='INDRA subnetwork statements',
                   db_rest_url='https://db.indra.bio',
                   ev_counts=ev_counts_by_hash,
                   source_counts=source_counts_by_hash)
html_str = ha.make_model()
ha.save_model('statements.html')

# %%
from IPython.core.display import HTML
# HTML(html_str)

# %% [markdown]
# ### NETWORK VISUALIZATION

# %% [markdown]
# We can also visualize the subnetwork acquired from INDRA Cogex using an INDRA built-in assembler

# %%
# Reference: https://pygraphviz.github.io/documentation/stable/install.html
# !pip install -q pygraphviz \
    --config-settings=--global-option=build_ext \
    --config-settings=--global-option="-I$(brew --prefix graphviz)/include" \
    --config-settings=--global-option="-L$(brew --prefix graphviz)/lib"

# %%
from indra.assemblers.graph.assembler import GraphAssembler

ga = GraphAssembler(stmts=stmts)
ga.make_model()
ga.save_pdf(file_name='graph.pdf', prog='dot')

# %% [markdown]
# ### Tabular Format

# %% [markdown]
# INDRA also has an assembler for displaying INDRA cogex results as a table.

# %%
from indra.assemblers.indranet.assembler import IndraNetAssembler

def add_evidence_column(stmt, ev_counts = ev_counts_by_hash):
    hash = stmt.get_hash(refresh=True)
    return ev_counts[hash]

indra_net_assembler = IndraNetAssembler(statements=stmts)
relations_table = indra_net_assembler.make_df(extra_columns=[('evidence_count', add_evidence_column)])
relations_table = relations_table.sort_values(by=['evidence_count'], ascending=False)
relations_table
# Out:
#     agA_name agB_name agA_ns agA_id agB_ns agB_id residue position  \
# 119     BRD4     BRD2   HGNC  13575   HGNC   1103    None     None
# 118     BRD2     BRD4   HGNC   1103   HGNC  13575    None     None
# 231     BRD4     BRD3   HGNC  13575   HGNC   1104    None     None
# 232     BRD3     BRD4   HGNC   1104   HGNC  13575    None     None
# 151     BRD2     BRD3   HGNC   1103   HGNC   1104    None     None
# ..       ...      ...    ...    ...    ...    ...     ...      ...
# 157    JMJD6     BRD2   HGNC  19355   HGNC   1103    None     None
# 158    JMJD6     BRD3   HGNC  19355   HGNC   1104    None     None
# 159     KRR1     NOP2   HGNC   5176   HGNC   7867    None     None
# 160     NOP2     KRR1   HGNC   7867   HGNC   5176    None     None
# 299     BRD2     BRD3   HGNC   1103   HGNC   1104    None     None
#
#       stmt_type  evidence_count          stmt_hash    belief   source_counts  \
# 119     Complex             113  12484535149707124  0.999950    {'reach': 1}
# 118     Complex             113  12484535149707124  0.999950    {'reach': 1}
# 231     Complex              51    359233681958482  0.999975  {'sparser': 1}
# 232     Complex              51    359233681958482  0.999975  {'sparser': 1}
# 151     Complex              42 -16515703320827288  0.999950  {'sparser': 1}
# ..          ...             ...                ...       ...             ...
# 157     Complex               1  34194495135899326  0.650000  {'sparser': 1}
# 158     Complex               1  34194495135899326  0.650000  {'sparser': 1}
# 159     Complex               1 -24130039704357981  0.980000  {'biogrid': 1}
# 160     Complex               1 -24130039704357981  0.980000  {'biogrid': 1}
# 299  Inhibition               1 -20414889449388058  0.650000    {'reach': 1}
#
#     initial_sign
# 119         None
# 118         None
# 231         None
# 232         None
# 151         None
# ..           ...
# 157         None
# 158         None
# 159         None
# 160         None
# 299         None
#
# [300 rows x 14 columns]

# %% [markdown]
# ### NDEx network upload
#
# **This only works if you have a working NDEx account with credentials configured locally**

# %%
import ndex2.client
from ndex2 import create_nice_cx_from_server
from indra.assemblers.cx import NiceCxAssembler
from indra.databases import ndex_client

ca = NiceCxAssembler(stmts, 'INDRA May Institute Network')
ncx = ca.make_model(self_loops=False)

style_network_id = '058c452f-b0d6-11ea-a4d3-0660b7976219'
style_ncx = create_nice_cx_from_server(
    server='http://test.ndexbio.org',
    uuid=style_network_id)
ncx.apply_style_from_network(style_ncx)

username, password = ndex_client.get_default_ndex_cred(ndex_cred=None)
ndex_args = {'server': 'http://public.ndexbio.org',
             'username': username,
             'password': password}
network_url = ncx.upload_to(**ndex_args)
network_url
# Out:
# Generating CX
# 'https://www.ndexbio.org/v2/network/2eccaaf8-0ee1-11ef-9621-005056ae23aa'

# %% [markdown]
# ## ADDITIONAL STEP: MORE CREATIVE WAYS TO DISPLAY DATA

# %% [markdown]
# ### Example 1: Simple Network Visualization with P-values, Correlation, LogFC Annotations

# %% [markdown]
# In this example, we take data from both MSstats functions `dataProcess` and `groupComparison`, gather metrics on p-value, correlation, and logFCs, and then contextualize that data with INDRA.

# %%
ABUNDANCE_PATH = "../data/ProteinLevelData.csv" # Set this path yourself
ABUNDANCE_GROUPS_FILTER = ['DMSO', 'DbET6']
def construct_abundance_df(filename):
    pandas_df = pd.read_csv(filename)
    pandas_df = pandas_df[pandas_df['GROUP'].isin(ABUNDANCE_GROUPS_FILTER)]
    return pandas_df

protein_abundance_df = construct_abundance_df(ABUNDANCE_PATH)
protein_abundance_df
# Out:
#          RUN      Protein  LogIntensities  \
# 0          1  1433B_HUMAN       12.873423
# 1          2  1433B_HUMAN       12.866217
# 2          3  1433B_HUMAN       12.686827
# 3          4  1433B_HUMAN       12.625462
# 4          5  1433B_HUMAN       12.538365
# ...      ...          ...             ...
# 1189700  145   ZZZ3_HUMAN       10.725469
# 1189701  146   ZZZ3_HUMAN       10.155338
# 1189702  147   ZZZ3_HUMAN        9.700678
# 1189703  148   ZZZ3_HUMAN       10.889323
# 1189704  149   ZZZ3_HUMAN       10.883954
#
#                                             originalRUN  GROUP  SUBJECT  \
# 0        230719_THP-1_Chrom_end2end_Plate1_DMSO_A02_DIA   DMSO        2
# 1        230719_THP-1_Chrom_end2end_Plate1_DMSO_A05_DIA   DMSO        5
# 2        230719_THP-1_Chrom_end2end_Plate1_DMSO_A10_DIA   DMSO       10
# 3        230719_THP-1_Chrom_end2end_Plate1_DMSO_A12_DIA   DMSO       12
# 4        230719_THP-1_Chrom_end2end_Plate1_DMSO_B01_DIA   DMSO       13
# ...                                                 ...    ...      ...
# 1189700  230719_THP-1_Chrom_end2end_Plate3_PF477736_D05  DbET6      233
# 1189701      230719_THP-1_Chrom_end2end_Plate3_DMSO_D06  DbET6      234
# 1189702      230719_THP-1_Chrom_end2end_Plate3_K975_D12  DbET6      240
# 1189703  230719_THP-1_Chrom_end2end_Plate3_VTP50469_F06  DbET6      258
# 1189704      230719_THP-1_Chrom_end2end_Plate3_K975_H01  DbET6      277
#
#          TotalGroupMeasurements  NumMeasuredFeature  MissingPercentage  \
# 0                          1210                  10                0.0
# 1                          1210                  10                0.0
# 2                          1210                  10                0.0
# 3                          1210                  10                0.0
# 4                          1210                  10                0.0
# ...                         ...                 ...                ...
# 1189700                     169                  10                0.0
# 1189701                     169                  10                0.0
# 1189702                     169                  10                0.0
# 1189703                     169                  10                0.0
# 1189704                     169                  10                0.0
#
#          more50missing  NumImputedFeature
# 0                False                  0
# 1                False                  0
# 2                False                  0
# 3                False                  0
# 4                False                  0
# ...                ...                ...
# 1189700          False                  0
# 1189701          False                  0
# 1189702          False                  0
# 1189703          False                  0
# 1189704          False                  0
#
# [657552 rows x 11 columns]

# %% [markdown]
# The `dataProcess` function outputs a dataset containing protein abundances for protein and biological replicate pair.  Using the protein abundances data, we can determine the correlation of abundance between pairs of proteins.

# %%
import numpy as np
def calculate_correlation_matrix(pvalue_df, protein_level_summary):
    data = {}
    subjects = protein_level_summary['SUBJECT'].unique()
    for protein in pvalue_df['Protein'].unique():
        data[protein] = []
        protein_level_df = protein_level_summary[protein_level_summary['Protein'] == protein]
        for subject in subjects:
            if subject in protein_level_df['SUBJECT'].values:
                protein_level_df_subject = protein_level_df[protein_level_df['SUBJECT'] == subject]
                data[protein].append(protein_level_df_subject['LogIntensities'].iloc[0])
            else:
                data[protein].append(np.nan)
    df = pd.DataFrame(data)
    corrM = df.corr() 
    return corrM

corr_matrix = calculate_correlation_matrix(pvalue_logfc_df, protein_abundance_df)
corr_matrix
# Out:
#              BRD2_HUMAN  BRD3_HUMAN  BRD4_HUMAN  CEBPZ_HUMAN  CRNL1_HUMAN  \
# BRD2_HUMAN     1.000000    0.797708    0.879262     0.019850    -0.207924
# BRD3_HUMAN     0.797708    1.000000    0.866766    -0.271567    -0.104151
# BRD4_HUMAN     0.879262    0.866766    1.000000    -0.027827    -0.155598
# CEBPZ_HUMAN    0.019850   -0.271567   -0.027827     1.000000     0.329054
# CRNL1_HUMAN   -0.207924   -0.104151   -0.155598     0.329054     1.000000
# DAZP1_HUMAN    0.598796    0.312657    0.552971     0.367810    -0.035805
# FUBP2_HUMAN    0.515316    0.307522    0.435370     0.363832     0.107018
# FUBP3_HUMAN    0.557954    0.226802    0.467304     0.413635     0.026768
# GTPB4_HUMAN   -0.093770   -0.387214   -0.034894     0.765247     0.230088
# HEAT3_HUMAN   -0.429264   -0.175765   -0.385975    -0.066058     0.231355
# HNRPD_HUMAN    0.539103    0.340189    0.351521     0.113002     0.014405
# KRR1_HUMAN    -0.118297   -0.192796   -0.068881     0.575716     0.396803
# NOP2_HUMAN    -0.225047   -0.302674   -0.274753     0.447506     0.527981
# PP1R8_HUMAN    0.621668    0.422305    0.472644     0.250952    -0.047657
# PRP18_HUMAN    0.255623    0.483052    0.275248    -0.262162     0.219325
# QKI_HUMAN      0.479966    0.660086    0.499226    -0.105441     0.151090
# TIA1_HUMAN     0.544447    0.185024    0.489967     0.483017    -0.183671
# UTP15_HUMAN   -0.466654   -0.322859   -0.423467     0.208180     0.600379
# WDR12_HUMAN   -0.265250   -0.183338   -0.236744     0.236918     0.558789
# WDR43_HUMAN   -0.253804   -0.316502   -0.388817     0.353536     0.566930
# WDR75_HUMAN   -0.157479   -0.223405   -0.146948     0.377506     0.510267
#
#              DAZP1_HUMAN  FUBP2_HUMAN  FUBP3_HUMAN  GTPB4_HUMAN  HEAT3_HUMAN  \
# BRD2_HUMAN      0.598796     0.515316     0.557954    -0.093770    -0.429264
# BRD3_HUMAN      0.312657     0.307522     0.226802    -0.387214    -0.175765
# BRD4_HUMAN      0.552971     0.435370     0.467304    -0.034894    -0.385975
# CEBPZ_HUMAN     0.367810     0.363832     0.413635     0.765247    -0.066058
# CRNL1_HUMAN    -0.035805     0.107018     0.026768     0.230088     0.231355
# DAZP1_HUMAN     1.000000     0.608002     0.743681     0.329881    -0.311158
# FUBP2_HUMAN     0.608002     1.000000     0.610191     0.168864    -0.218615
# FUBP3_HUMAN     0.743681     0.610191     1.000000     0.419721    -0.322835
# GTPB4_HUMAN     0.329881     0.168864     0.419721     1.000000    -0.044000
# HEAT3_HUMAN    -0.311158    -0.218615    -0.322835    -0.044000     1.000000
# HNRPD_HUMAN     0.545040     0.584445     0.488188    -0.114297    -0.274164
# KRR1_HUMAN      0.199983     0.282158     0.156421     0.484970     0.199914
# NOP2_HUMAN      0.006942     0.194035     0.070900     0.288195     0.096674
# PP1R8_HUMAN     0.595334     0.513343     0.604436     0.112460    -0.343605
# PRP18_HUMAN     0.062600     0.237327     0.042284    -0.407856     0.141172
# QKI_HUMAN       0.372729     0.469106     0.303556    -0.330488    -0.025871
# TIA1_HUMAN      0.751419     0.589631     0.790524     0.534385    -0.320925
# UTP15_HUMAN    -0.268644    -0.048102    -0.295023     0.066697     0.445552
# WDR12_HUMAN    -0.070602     0.109012    -0.032122     0.030891     0.254046
# WDR43_HUMAN    -0.132739     0.165000     0.020199     0.189041     0.246794
# WDR75_HUMAN     0.042042     0.105673     0.132255     0.265675    -0.046507
#
#              ...  KRR1_HUMAN  NOP2_HUMAN  PP1R8_HUMAN  PRP18_HUMAN  QKI_HUMAN  \
# BRD2_HUMAN   ...   -0.118297   -0.225047     0.621668     0.255623   0.479966
# BRD3_HUMAN   ...   -0.192796   -0.302674     0.422305     0.483052   0.660086
# BRD4_HUMAN   ...   -0.068881   -0.274753     0.472644     0.275248   0.499226
# CEBPZ_HUMAN  ...    0.575716    0.447506     0.250952    -0.262162  -0.105441
# CRNL1_HUMAN  ...    0.396803    0.527981    -0.047657     0.219325   0.151090
# DAZP1_HUMAN  ...    0.199983    0.006942     0.595334     0.062600   0.372729
# FUBP2_HUMAN  ...    0.282158    0.194035     0.513343     0.237327   0.469106
# FUBP3_HUMAN  ...    0.156421    0.070900     0.604436     0.042284   0.303556
# GTPB4_HUMAN  ...    0.484970    0.288195     0.112460    -0.407856  -0.330488
# HEAT3_HUMAN  ...    0.199914    0.096674    -0.343605     0.141172  -0.025871
# HNRPD_HUMAN  ...    0.125444    0.092278     0.563730     0.317165   0.557362
# KRR1_HUMAN   ...    1.000000    0.398750     0.056222    -0.123099  -0.017384
# NOP2_HUMAN   ...    0.398750    1.000000     0.054507     0.052304  -0.065705
# PP1R8_HUMAN  ...    0.056222    0.054507     1.000000     0.204392   0.499983
# PRP18_HUMAN  ...   -0.123099    0.052304     0.204392     1.000000   0.599861
# QKI_HUMAN    ...   -0.017384   -0.065705     0.499983     0.599861   1.000000
# TIA1_HUMAN   ...    0.231466   -0.018197     0.548012    -0.097829   0.169855
# UTP15_HUMAN  ...    0.421255    0.488759    -0.286920     0.117953  -0.017787
# WDR12_HUMAN  ...    0.263342    0.491605     0.039424     0.305236   0.226580
# WDR43_HUMAN  ...    0.412868    0.588624     0.045308     0.109525   0.060119
# WDR75_HUMAN  ...    0.286653    0.490429     0.149858    -0.033367   0.018128
#
#              TIA1_HUMAN  UTP15_HUMAN  WDR12_HUMAN  WDR43_HUMAN  WDR75_HUMAN
# BRD2_HUMAN     0.544447    -0.466654    -0.265250    -0.253804    -0.157479
# BRD3_HUMAN     0.185024    -0.322859    -0.183338    -0.316502    -0.223405
# BRD4_HUMAN     0.489967    -0.423467    -0.236744    -0.388817    -0.146948
# CEBPZ_HUMAN    0.483017     0.208180     0.236918     0.353536     0.377506
# CRNL1_HUMAN   -0.183671     0.600379     0.558789     0.566930     0.510267
# DAZP1_HUMAN    0.751419    -0.268644    -0.070602    -0.132739     0.042042
# FUBP2_HUMAN    0.589631    -0.048102     0.109012     0.165000     0.105673
# FUBP3_HUMAN    0.790524    -0.295023    -0.032122     0.020199     0.132255
# GTPB4_HUMAN    0.534385     0.066697     0.030891     0.189041     0.265675
# HEAT3_HUMAN   -0.320925     0.445552     0.254046     0.246794    -0.046507
# HNRPD_HUMAN    0.428906    -0.083049     0.235416     0.175258     0.073476
# KRR1_HUMAN     0.231466     0.421255     0.263342     0.412868     0.286653
# NOP2_HUMAN    -0.018197     0.488759     0.491605     0.588624     0.490429
# PP1R8_HUMAN    0.548012    -0.286920     0.039424     0.045308     0.149858
# PRP18_HUMAN   -0.097829     0.117953     0.305236     0.109525    -0.033367
# QKI_HUMAN      0.169855    -0.017787     0.226580     0.060119     0.018128
# TIA1_HUMAN     1.000000    -0.386969    -0.180420    -0.050802    -0.023821
# UTP15_HUMAN   -0.386969     1.000000     0.462224     0.584313     0.331612
# WDR12_HUMAN   -0.180420     0.462224     1.000000     0.519296     0.411982
# WDR43_HUMAN   -0.050802     0.584313     0.519296     1.000000     0.437904
# WDR75_HUMAN   -0.023821     0.331612     0.411982     0.437904     1.000000
#
# [21 rows x 21 columns]

# %%
LOG_FC_FILTER = 0.25
pvalue_logfc_df['log2FC'] = pvalue_logfc_df['log2FC'].astype(float)
logfc_proteins = pvalue_logfc_df[pvalue_logfc_df['log2FC'] > LOG_FC_FILTER]
logfc_proteins
# Out:
#             Protein       Label    log2FC        SE     Tvalue     DF  \
# 19890    BRD2_HUMAN  DMSO-DbET6  2.046185  0.114339  17.895836  260.0
# 19935    BRD3_HUMAN  DMSO-DbET6  3.333428  0.126571  26.336522  257.0
# 19980    BRD4_HUMAN  DMSO-DbET6  2.668935  0.101283  26.351317  257.0
# 41580   DAZP1_HUMAN  DMSO-DbET6  0.617508  0.099537   6.203818  260.0
# 66060   FUBP2_HUMAN  DMSO-DbET6  0.291045  0.077226   3.768747  260.0
# 66105   FUBP3_HUMAN  DMSO-DbET6  0.300410  0.069882   4.298798  260.0
# 137745  PP1R8_HUMAN  DMSO-DbET6  0.358282  0.069056   5.188314  260.0
# 140535  PRP18_HUMAN  DMSO-DbET6  0.485713  0.120799   4.020834  260.0
# 145440    QKI_HUMAN  DMSO-DbET6  0.336985  0.055130   6.112567  260.0
# 196155   TIA1_HUMAN  DMSO-DbET6  0.476791  0.105361   4.525306  260.0
#
#               pvalue  adj.pvalue issue  MissingPercentage  \
# 19890   0.000000e+00    0.000000   NaN           0.310067
# 19935   0.000000e+00    0.000000   NaN           0.252349
# 19980   0.000000e+00    0.000000   NaN           0.118121
# 41580   2.159950e-09    0.000002   NaN           0.286577
# 66060   2.030530e-04    0.047824   NaN           0.017450
# 66105   2.430235e-05    0.008941   NaN           0.095302
# 137745  4.275951e-07    0.000235   NaN           0.045638
# 140535  7.603588e-05    0.022122   NaN           0.049664
# 145440  3.570594e-09    0.000003   NaN           0.000000
# 196155  9.182867e-06    0.004129   NaN           0.058389
#
#         ImputationPercentage
# 19890                    0.0
# 19935                    0.0
# 19980                    0.0
# 41580                    0.0
# 66060                    0.0
# 66105                    0.0
# 137745                   0.0
# 140535                   0.0
# 145440                   0.0
# 196155                   0.0

# %%
CORRELATION_FILTER = 0.3
EVIDENCE_FILTER = 10

for node in ga.graph.nodes():
    node_properties = {
        'color': '#808080',
        'shape': 'Mrecord',
        'fontsize': 8
    }
    protein_id = hgnc_gene_name_to_uniprot_mapping.get(node)
    if not protein_id:
        ga.graph.add_node(node,
                          label=node,
                          **node_properties)
    elif protein_id in logfc_proteins['Protein'].values:
        node_properties['color'] = '#00FF00'
        logFC_value = round(pvalue_logfc_df[pvalue_logfc_df['Protein'] == protein_id]['log2FC'].iloc[0], 2)
        ga.graph.add_node(node,
                          label=f'{node}: {logFC_value} LogFC',
                          **node_properties)
    else:
        node_properties['color'] = '#FF0000'
        logFC_value = round(pvalue_logfc_df[pvalue_logfc_df['Protein'] == protein_id]['log2FC'].iloc[0], 2)
        ga.graph.add_node(node,
                          label=f'{node}: {logFC_value} LogFC',
                          **node_properties)

color = '#ff0000'
color_default = '#000000'
for edge in ga.graph.edges():
    params = {'color': color_default,
              'arrowhead': 'normal',
              'dir': 'forward'}
    if edge[0] in hgnc_gene_name_to_uniprot_mapping.keys() and \
        edge[1] in hgnc_gene_name_to_uniprot_mapping.keys():
        uniprot_0 = hgnc_gene_name_to_uniprot_mapping.get(edge[0])
        uniprot_1 = hgnc_gene_name_to_uniprot_mapping.get(edge[1])
        correlation = round(corr_matrix[uniprot_0][uniprot_1], 2)
        evidence_df = relations_table[relations_table['agA_name'] == edge[0]]
        evidence_df = evidence_df[evidence_df['agB_name'] == edge[1]]
        evidence = evidence_df['evidence_count'].iloc[0]
        if evidence >= EVIDENCE_FILTER and correlation > CORRELATION_FILTER:
            params['color'] = '#00ff00'
        else:
            params['color'] = color
        params['label'] = f'Correlation: {correlation}, Evidence: {evidence}'
    ga.graph.add_edge(edge[0], edge[1], **params)

ga.save_pdf(file_name='graph_annotations.pdf', prog='dot')

# %% [markdown]
# ### Example 2: Plotly Visualization

# %%
import math
import random
import networkx as nx
import plotly.graph_objects as go
from indra.databases import hgnc_client

# %%
def initialize_networkx_graph(subnetwork_relations, filter_bidirectional=False):
    """Return a networkx graph from the INDRA relations."""
    G = nx.DiGraph()
    
    # Get max evidence count of "Complex" INDRA statements for each pair of proteins.
    ev_counts = {}
    for entry in subnetwork_relations:
        if entry['data']['stmt_type'] == "Complex":
            if ev_counts.get((entry['source_id'], entry['target_id'])):
                ev_counts[(entry['source_id'], entry['target_id'])] = \
                max(int(entry['data']['evidence_count']), int(ev_counts.get((entry['source_id'], entry['target_id']))))
            else:
                ev_counts[(entry['source_id'], entry['target_id'])] = int(entry['data']['evidence_count'])

    # Construct graph object
    for entry in subnetwork_relations:
        source = entry['source_id']
        target = entry['target_id']
        
        if filter_bidirectional:
            # If there is a statement with opposite direction and more evidence
            # then we skip this one
            if ev_counts[(source, target)] < ev_counts.get((target, source), 0):
                continue

        # Add nodes to graph
        source_name = hgnc_client.get_hgnc_name(source)
        target_name = hgnc_client.get_hgnc_name(target)
        G.add_node(source, label=source_name)
        G.add_node(target, label=target_name)
            
        # Add the edge to the graph
        G.add_edge(
            source,
            target,
            evidence_count=ev_counts[(source, target)],
            belief=entry['data']['belief'],
            stmt_type=entry['data']['stmt_type']
        )

    return G

# %%
def find_communities(G, weight='evidence_count'):
    """Return the communities of a networkx graph using a custom weight attribute."""
    return nx.community.louvain_communities(G, weight=weight)

# %%
def generate_node_initial_positions(G, communities):
    """Return node positions of a networkx graph based on communities."""
    initial_pos = {}
    circle_r = 1
    big_r = 1
    pi = math.pi
    centers = [(math.cos(2 * pi / len(communities) * x) * big_r, math.sin(2 * pi / len(communities) * x) * big_r)
               for x in range(0, len(communities))]
    for index, nodes in enumerate(communities):
        for node in nodes:
            alpha = 2 * math.pi * random.random()
            r = circle_r * math.sqrt(random.random())
            x = r * math.cos(alpha) + centers[index][0]
            y = r * math.sin(alpha) + centers[index][1]
            initial_pos[node] = [x, y]
            nx.set_node_attributes(G, {node: index}, name='community')
    
    return initial_pos

# %%
def apply_layout_to_graph(G, initial_pos, k=50, iterations=100, weight='evidence_count'):
    """Apply custom layout positions to a networkx graph."""
    pos = nx.spring_layout(G, weight=weight, k=k / math.sqrt(len(G.nodes)), pos=initial_pos, iterations=iterations)
    for node in G.nodes():
        x = pos[node][0]
        y = pos[node][1]
        nx.set_node_attributes(G, {node: [x, y]}, name='pos')
    return G

# %%
def construct_networkx_graph(subnetwork_relations):
    """Return a custom networkx graph from INDRA subnetwork relations."""
    G = initialize_networkx_graph(subnetwork_relations)
    communities = find_communities(G)
    initial_pos = generate_node_initial_positions(G, communities)
    apply_layout_to_graph(G, initial_pos)
    return G


G = construct_networkx_graph(subnetwork_relations)

# %%
def construct_arrows(G):
    """Return list of directed edges for network visualization."""
    arrow_list = []
    for edge in G.edges():
        x0, y0 = G.nodes[edge[0]]['pos']
        x1, y1 = G.nodes[edge[1]]['pos']

        arrow = go.layout.Annotation(dict(
            x=x0,
            y=y0,
            xref="x", yref="y",
            showarrow=True,
            axref="x", ayref='y',
            ax=x1,
            ay=y1,
            arrowhead=3,
            arrowwidth=min(2, G.edges[edge]['evidence_count']),
            arrowcolor='lightgreen')
        )

        arrow_list.append(arrow)
    return arrow_list

# %%
def construct_arrow_labels(G):
    """Return custom edge labels for network visualization."""
    mnode_x, mnode_y, mnode_txt = [], [], []
    for edge in G.edges():
        x0, y0 = G.nodes[edge[0]]['pos']
        x1, y1 = G.nodes[edge[1]]['pos']
        name0 = G.nodes[edge[0]]['label']
        name1 = G.nodes[edge[1]]['label']

        mnode_x.extend([(x0 + x1) / 2])
        mnode_y.extend([(y0 + y1) / 2])
        mnode_txt.extend([f'{name0}->{name1} evidence count: {G.edges[edge]["evidence_count"]}'])

    mnode_trace = go.Scatter(
        x=mnode_x, y=mnode_y,
        mode="markers",
        showlegend=False,
        hovertext=mnode_txt,
        hovertemplate="Edge %{hovertext}<extra></extra>",
        marker=go.scatter.Marker(opacity=0)
    )
    
    return mnode_trace

# %%
def construct_node_trace(G):
    """Return custom nodes for network visualization"""
    node_x = []
    node_y = []
    for node in G.nodes():
        x, y = G.nodes[node]['pos']
        node_x.append(x)
        node_y.append(y)

    node_trace = go.Scatter(
        x=node_x, y=node_y,
        mode='markers+text',
        hoverinfo='text',
        text=[data['label'] for node, data in list(G.nodes(data=True))],
        textposition="bottom center",
        marker=dict(
            showscale=True,
            colorscale='YlGnBu',
            reversescale=True,
            color=[],
            size=30,
            colorbar=dict(
                thickness=15,
                title='Cluster ID',
                xanchor='left',
                titleside='right'
            ),
            line_width=2))
    
    node_colors = []
    node_text = []
    for node in G.nodes():
        node_colors.append(G.nodes[node]['community'])

    node_trace.marker.color = node_colors

    return node_trace

# %%
def show_plotly_graph(nodes, arrows):
    """Visualize the network based on the list of nodes and arrows."""
    fig = go.Figure(data=nodes,
                    layout=go.Layout(
                        title='<br>Network graph made with Python',
                        font=dict(
                            family="Courier New, monospace",
                            size=10,
                            color="Black"
                        ),
                        annotations=arrows,
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=20, l=5, r=5, t=40),
                        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                    )
    fig.show(renderer="notebook")

# %%
def create_plotly_graph(G):
    """Generate and visualize a custom network from a networkx graph."""
    edges = construct_arrows(G)
    edge_midpoints = construct_arrow_labels(G)
    nodes = construct_node_trace(G)
    show_plotly_graph([edge_midpoints, nodes], edges)

# %%
create_plotly_graph(G)

# %%
G.nodes['13575']
# Out:
# {'label': 'BRD4',
#  'community': 0,
#  'pos': [0.9528133707816417, 0.19311777236587424]}
