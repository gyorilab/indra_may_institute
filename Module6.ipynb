# %%
import requests
from indra.databases import hgnc_client

# %%
base_url = 'https://discovery.indra.bio/api/'

# %% [markdown]
# Get diseases for a given clinical trial

# %%
url = base_url + 'get_diseases_for_trial'
payload = {
  "trial": [
    "CLINICALTRIALS",
    "NCT00000114"
  ]
}
res = requests.post(url, json=payload)
print(res.status_code)
res.json()
# Out:
# 200
# [{'data': {'db_id': 'D012174',
#    'db_ns': 'MESH',
#    'name': 'Retinitis Pigmentosa',
#    'type': 'disease'},
#   'labels': ['BioEntity']}]

# %% [markdown]
# Get pathways that a gene is involved in

# %%
url = base_url + 'get_pathways_for_gene'

hgnc_id = hgnc_client.get_hgnc_id('CHEK1')

payload = {
  "gene": [
    "HGNC",
    hgnc_id
  ]
}
res = requests.post(url, json=payload)
res.json()
# Out:
# [{'data': {'db_id': 'R-HSA-9006934',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by Receptor Tyrosine Kinases',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-8953750',
#    'db_ns': 'REACTOME',
#    'name': 'Transcriptional Regulation by E2F6',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-75035',
#    'db_ns': 'REACTOME',
#    'name': 'Chk1/Chk2(Cds1) mediated inactivation of Cyclin B:Cdk1 complex',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-74160',
#    'db_ns': 'REACTOME',
#    'name': 'Gene expression (Transcription)',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-212436',
#    'db_ns': 'REACTOME',
#    'name': 'Generic Transcription Pathway',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-73894',
#    'db_ns': 'REACTOME',
#    'name': 'DNA Repair',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-73857',
#    'db_ns': 'REACTOME',
#    'name': 'RNA Polymerase II Transcription',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-69620',
#    'db_ns': 'REACTOME',
#    'name': 'Cell Cycle Checkpoints',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-69615',
#    'db_ns': 'REACTOME',
#    'name': 'G1/S DNA Damage Checkpoints',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-69613',
#    'db_ns': 'REACTOME',
#    'name': 'p53-Independent G1/S DNA damage checkpoint',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-69610',
#    'db_ns': 'REACTOME',
#    'name': 'p53-Independent DNA Damage Response',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-69601',
#    'db_ns': 'REACTOME',
#    'name': 'Ubiquitin Mediated Degradation of Phosphorylated Cdc25A',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-69481',
#    'db_ns': 'REACTOME',
#    'name': 'G2/M Checkpoints',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-69473',
#    'db_ns': 'REACTOME',
#    'name': 'G2/M DNA damage checkpoint',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-176187',
#    'db_ns': 'REACTOME',
#    'name': 'Activation of ATR in response to replication stress',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-6804756',
#    'db_ns': 'REACTOME',
#    'name': 'Regulation of TP53 Activity through Phosphorylation',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-6796648',
#    'db_ns': 'REACTOME',
#    'name': 'TP53 Regulates Transcription of DNA Repair Genes',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5693616',
#    'db_ns': 'REACTOME',
#    'name': 'Presynaptic phase of homologous DNA pairing and strand exchange',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5693607',
#    'db_ns': 'REACTOME',
#    'name': 'Processing of DNA double-strand break ends',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5693579',
#    'db_ns': 'REACTOME',
#    'name': 'Homologous DNA Pairing and Strand Exchange',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5693567',
#    'db_ns': 'REACTOME',
#    'name': 'HDR through Homologous Recombination (HRR) or Single Strand Annealing (SSA)',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5693538',
#    'db_ns': 'REACTOME',
#    'name': 'Homology Directed Repair',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5693532',
#    'db_ns': 'REACTOME',
#    'name': 'DNA Double-Strand Break Repair',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5685942',
#    'db_ns': 'REACTOME',
#    'name': 'HDR through Homologous Recombination (HRR)',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-1640170',
#    'db_ns': 'REACTOME',
#    'name': 'Cell Cycle',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-162582',
#    'db_ns': 'REACTOME',
#    'name': 'Signal Transduction',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5633007',
#    'db_ns': 'REACTOME',
#    'name': 'Regulation of TP53 Activity',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-1433557',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by SCF-KIT',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-3700989',
#    'db_ns': 'REACTOME',
#    'name': 'Transcriptional Regulation by TP53',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP707',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'DNA damage response',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5300',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'TROP2 regulatory signaling',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4946',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'DNA repair pathways full network',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4016',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'DNA IR damage and cellular response via ATR',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3959',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'DNA IR double strand breaks and cellular response via ATM',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3878',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'ATM signaling in development and disease ',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3875',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'ATR signaling',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3651',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Pathways affected in adenoid cystic carcinoma',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2516',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'ATM signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2446',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Retinoblastoma gene in cancer',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2263',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Androgen receptor network in prostate cancer',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP1971',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Integrated cancer pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP179',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Cell cycle',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP1530',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'miRNA regulation of DNA damage response',
#    'version': '20240101'},
#   'labels': ['BioEntity']}]

# %% [markdown]
# Get shared pathways for a list of genes

# %%
url = base_url + 'get_shared_pathways_for_genes'

gene_names = ['BRD2', 'BRD3', 'BRD4']
hgnc_ids = [hgnc_client.get_hgnc_id(gene_name) for gene_name in gene_names]
payload = {"genes": [['HGNC', hgnc_id] for hgnc_id in hgnc_ids]}
payload
# Out:
# {'genes': [['HGNC', '1103'], ['HGNC', '1104'], ['HGNC', '13575']]}

# %%
res = requests.post(url, json=payload)
res.json()
# Out:
# []

# %%
gene_names = ['MAPK1', 'MAPK3']
hgnc_ids = [hgnc_client.get_hgnc_id(gene_name) for gene_name in gene_names]
payload = {"genes": [['HGNC', hgnc_id] for hgnc_id in hgnc_ids]}
res = requests.post(url, json=payload)
res.json()
# Out:
# [{'data': {'db_id': 'R-HSA-9658195',
#    'db_ns': 'REACTOME',
#    'name': 'Leishmania infection',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9656223',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by RAF1 mutants',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9652169',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by MAP2K mutants',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9649948',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling downstream of RAS mutants',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9637690',
#    'db_ns': 'REACTOME',
#    'name': 'Response of Mtb to phagocytosis',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9635486',
#    'db_ns': 'REACTOME',
#    'name': 'Infection with Mycobacterium tuberculosis',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9635465',
#    'db_ns': 'REACTOME',
#    'name': 'Suppression of apoptosis',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9634815',
#    'db_ns': 'REACTOME',
#    'name': 'Transcriptional Regulation by NPAS4',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9634638',
#    'db_ns': 'REACTOME',
#    'name': 'Estrogen-dependent nuclear events downstream of ESR-membrane signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9627069',
#    'db_ns': 'REACTOME',
#    'name': 'Regulation of the apoptosome activity',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-937061',
#    'db_ns': 'REACTOME',
#    'name': 'TRIF(TICAM1)-mediated TLR4 signaling ',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-913531',
#    'db_ns': 'REACTOME',
#    'name': 'Interferon Signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9009391',
#    'db_ns': 'REACTOME',
#    'name': 'Extra-nuclear estrogen signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9006936',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by TGFB family members',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9006934',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by Receptor Tyrosine Kinases',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9006931',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by Nuclear Receptors',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9006925',
#    'db_ns': 'REACTOME',
#    'name': 'Intracellular signaling by second messengers',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-8953897',
#    'db_ns': 'REACTOME',
#    'name': 'Cellular responses to stimuli',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-8943724',
#    'db_ns': 'REACTOME',
#    'name': 'Regulation of PTEN gene transcription',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-8941326',
#    'db_ns': 'REACTOME',
#    'name': 'RUNX2 regulates bone development',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-8940973',
#    'db_ns': 'REACTOME',
#    'name': 'RUNX2 regulates osteoblast differentiation',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-8939211',
#    'db_ns': 'REACTOME',
#    'name': 'ESR-mediated signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-8878166',
#    'db_ns': 'REACTOME',
#    'name': 'Transcriptional regulation by RUNX2',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-881907',
#    'db_ns': 'REACTOME',
#    'name': 'Gastrin-CREB signalling pathway via PKC and MAPK',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-879415',
#    'db_ns': 'REACTOME',
#    'name': 'Advanced glycosylation endproduct receptor signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-877300',
#    'db_ns': 'REACTOME',
#    'name': 'Interferon gamma signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-76002',
#    'db_ns': 'REACTOME',
#    'name': 'Platelet activation, signaling and aggregation',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-74752',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by Insulin receptor',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-74751',
#    'db_ns': 'REACTOME',
#    'name': 'Insulin receptor signalling cascade',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-74749',
#    'db_ns': 'REACTOME',
#    'name': 'Signal attenuation',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-74160',
#    'db_ns': 'REACTOME',
#    'name': 'Gene expression (Transcription)',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-212436',
#    'db_ns': 'REACTOME',
#    'name': 'Generic Transcription Pathway',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-73857',
#    'db_ns': 'REACTOME',
#    'name': 'RNA Polymerase II Transcription',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-2029482',
#    'db_ns': 'REACTOME',
#    'name': 'Regulation of actin dynamics for phagocytic cup formation',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-2029480',
#    'db_ns': 'REACTOME',
#    'name': 'Fcgamma receptor (FCGR) dependent phagocytosis',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-202670',
#    'db_ns': 'REACTOME',
#    'name': 'ERKs are inactivated',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-199418',
#    'db_ns': 'REACTOME',
#    'name': 'Negative regulation of the PI3K/AKT network',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-198753',
#    'db_ns': 'REACTOME',
#    'name': 'ERK/MAPK targets',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-198725',
#    'db_ns': 'REACTOME',
#    'name': 'Nuclear Events (kinase and transcription factor activation)',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-195258',
#    'db_ns': 'REACTOME',
#    'name': 'RHO GTPase Effectors',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-194315',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by Rho GTPases',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-69278',
#    'db_ns': 'REACTOME',
#    'name': 'Cell Cycle, Mitotic',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-190236',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by FGFR',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-187687',
#    'db_ns': 'REACTOME',
#    'name': 'Signalling to ERKs',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-187037',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by NTRK1 (TRKA)',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-181438',
#    'db_ns': 'REACTOME',
#    'name': 'Toll Like Receptor 2 (TLR2) Cascade',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-68886',
#    'db_ns': 'REACTOME',
#    'name': 'M Phase',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-68875',
#    'db_ns': 'REACTOME',
#    'name': 'Mitotic Prophase',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-6811558',
#    'db_ns': 'REACTOME',
#    'name': 'PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-170968',
#    'db_ns': 'REACTOME',
#    'name': 'Frs2-mediated activation',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-6807070',
#    'db_ns': 'REACTOME',
#    'name': 'PTEN Regulation',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-170834',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by TGF-beta Receptor Complex',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-169893',
#    'db_ns': 'REACTOME',
#    'name': 'Prolonged ERK activation events',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-168898',
#    'db_ns': 'REACTOME',
#    'name': 'Toll-like Receptor Cascades',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-6802957',
#    'db_ns': 'REACTOME',
#    'name': 'Oncogenic MAPK signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-6802955',
#    'db_ns': 'REACTOME',
#    'name': 'Paradoxical activation of RAF signaling by kinase inactive BRAF',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-6802952',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by BRAF and RAF1 fusions',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-6802949',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by RAS mutants',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-6802948',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by high-kinase activity BRAF mutants',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-6802946',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by moderate kinase activity BRAF mutants',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-168256',
#    'db_ns': 'REACTOME',
#    'name': 'Immune System',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-168249',
#    'db_ns': 'REACTOME',
#    'name': 'Innate Immune System',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-168188',
#    'db_ns': 'REACTOME',
#    'name': 'Toll Like Receptor TLR6:TLR2 Cascade',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-168181',
#    'db_ns': 'REACTOME',
#    'name': 'Toll Like Receptor 7/8 (TLR7/8) Cascade',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-168179',
#    'db_ns': 'REACTOME',
#    'name': 'Toll Like Receptor TLR1:TLR2 Cascade',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-168176',
#    'db_ns': 'REACTOME',
#    'name': 'Toll Like Receptor 5 (TLR5) Cascade',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-168164',
#    'db_ns': 'REACTOME',
#    'name': 'Toll Like Receptor 3 (TLR3) Cascade',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-168142',
#    'db_ns': 'REACTOME',
#    'name': 'Toll Like Receptor 10 (TLR10) Cascade',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-168138',
#    'db_ns': 'REACTOME',
#    'name': 'Toll Like Receptor 9 (TLR9) Cascade',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-166520',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by NTRKs',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-166166',
#    'db_ns': 'REACTOME',
#    'name': 'MyD88-independent TLR4 cascade ',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5684996',
#    'db_ns': 'REACTOME',
#    'name': 'MAPK1/MAPK3 signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-166058',
#    'db_ns': 'REACTOME',
#    'name': 'MyD88:MAL(TIRAP) cascade initiated on plasma membrane',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-166016',
#    'db_ns': 'REACTOME',
#    'name': 'Toll Like Receptor 4 (TLR4) Cascade',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5683057',
#    'db_ns': 'REACTOME',
#    'name': 'MAPK family signaling cascades',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5675221',
#    'db_ns': 'REACTOME',
#    'name': 'Negative regulation of MAPK pathway',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5674499',
#    'db_ns': 'REACTOME',
#    'name': 'Negative feedback regulation of MAPK pathway',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5674135',
#    'db_ns': 'REACTOME',
#    'name': 'MAP2K and MAPK activation',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5673001',
#    'db_ns': 'REACTOME',
#    'name': 'RAF/MAP kinase cascade',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-1643685',
#    'db_ns': 'REACTOME',
#    'name': 'Disease',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5668599',
#    'db_ns': 'REACTOME',
#    'name': 'RHO GTPases Activate NADPH Oxidases',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5663213',
#    'db_ns': 'REACTOME',
#    'name': 'RHO GTPases Activate WASPs and WAVEs',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-1640170',
#    'db_ns': 'REACTOME',
#    'name': 'Cell Cycle',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5663205',
#    'db_ns': 'REACTOME',
#    'name': 'Infectious disease',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-162658',
#    'db_ns': 'REACTOME',
#    'name': 'Golgi Cisternae Pericentriolar Stack Reorganization',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5663202',
#    'db_ns': 'REACTOME',
#    'name': 'Diseases of signal transduction by growth factor receptors and second messengers',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-162582',
#    'db_ns': 'REACTOME',
#    'name': 'Signal Transduction',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5654743',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by FGFR4',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5654741',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by FGFR3',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5654738',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by FGFR2',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5654736',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by FGFR1',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5654733',
#    'db_ns': 'REACTOME',
#    'name': 'Negative regulation of FGFR4 signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5654732',
#    'db_ns': 'REACTOME',
#    'name': 'Negative regulation of FGFR3 signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5654727',
#    'db_ns': 'REACTOME',
#    'name': 'Negative regulation of FGFR2 signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5654726',
#    'db_ns': 'REACTOME',
#    'name': 'Negative regulation of FGFR1 signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-1502540',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by Activin',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-1295596',
#    'db_ns': 'REACTOME',
#    'name': 'Spry regulation of FGF signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-1280215',
#    'db_ns': 'REACTOME',
#    'name': 'Cytokine Signaling in Immune system',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-1266738',
#    'db_ns': 'REACTOME',
#    'name': 'Developmental Biology',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-5357801',
#    'db_ns': 'REACTOME',
#    'name': 'Programmed Cell Death',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-982772',
#    'db_ns': 'REACTOME',
#    'name': 'Growth hormone receptor signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-1257604',
#    'db_ns': 'REACTOME',
#    'name': 'PIP3 activates AKT signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-1181150',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by NODAL',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9824443',
#    'db_ns': 'REACTOME',
#    'name': 'Parasitic Infection Pathways',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-456926',
#    'db_ns': 'REACTOME',
#    'name': 'Thrombin signalling through proteinase activated receptors (PARs)',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-112409',
#    'db_ns': 'REACTOME',
#    'name': 'RAF-independent MAPK1/3 activation',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-112316',
#    'db_ns': 'REACTOME',
#    'name': 'Neuronal System',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9824439',
#    'db_ns': 'REACTOME',
#    'name': 'Bacterial Infection Pathways',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-450341',
#    'db_ns': 'REACTOME',
#    'name': 'Activation of the AP-1 family of transcription factors',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-450294',
#    'db_ns': 'REACTOME',
#    'name': 'MAP kinase activation',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-450282',
#    'db_ns': 'REACTOME',
#    'name': 'MAPK targets/ Nuclear events mediated by MAP kinases',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-112315',
#    'db_ns': 'REACTOME',
#    'name': 'Transmission across Chemical Synapses',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-449147',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by Interleukins',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-112314',
#    'db_ns': 'REACTOME',
#    'name': 'Neurotransmitter receptors and postsynaptic signal transmission',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-448424',
#    'db_ns': 'REACTOME',
#    'name': 'Interleukin-17 signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-111471',
#    'db_ns': 'REACTOME',
#    'name': 'Apoptotic factor-mediated response',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-111461',
#    'db_ns': 'REACTOME',
#    'name': 'Cytochrome c-mediated apoptotic response',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-111458',
#    'db_ns': 'REACTOME',
#    'name': 'Formation of apoptosome',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-109606',
#    'db_ns': 'REACTOME',
#    'name': 'Intrinsic Pathway for Apoptosis',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9768919',
#    'db_ns': 'REACTOME',
#    'name': 'NPAS4 regulates expression of target genes',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-445144',
#    'db_ns': 'REACTOME',
#    'name': 'Signal transduction by L1',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-444257',
#    'db_ns': 'REACTOME',
#    'name': 'RSK activation',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-442755',
#    'db_ns': 'REACTOME',
#    'name': 'Activation of NMDA receptors and postsynaptic events',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-442742',
#    'db_ns': 'REACTOME',
#    'name': 'CREB1 phosphorylation through NMDA receptor-mediated activation of RAS signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-109582',
#    'db_ns': 'REACTOME',
#    'name': 'Hemostasis',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-438064',
#    'db_ns': 'REACTOME',
#    'name': 'Post NMDA receptor activation events',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-109581',
#    'db_ns': 'REACTOME',
#    'name': 'Apoptosis',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-975871',
#    'db_ns': 'REACTOME',
#    'name': 'MyD88 cascade initiated on plasma membrane',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-975155',
#    'db_ns': 'REACTOME',
#    'name': 'MyD88 dependent cascade initiated on endosome',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-975138',
#    'db_ns': 'REACTOME',
#    'name': 'TRAF6 mediated induction of NFkB and MAP kinases upon TLR7/8 or 9 activation',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-422475',
#    'db_ns': 'REACTOME',
#    'name': 'Axon guidance',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9732724',
#    'db_ns': 'REACTOME',
#    'name': 'IFNG signaling activates MAPKs',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9725371',
#    'db_ns': 'REACTOME',
#    'name': 'Nuclear events stimulated by ALK signaling in cancer',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9725370',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by ALK fusions and activated point mutants',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9716542',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by Rho GTPases, Miro GTPases and RHOBTB3',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-416476',
#    'db_ns': 'REACTOME',
#    'name': 'G alpha (q) signalling events',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9700206',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by ALK in cancer',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9675108',
#    'db_ns': 'REACTOME',
#    'name': 'Nervous system development',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9664422',
#    'db_ns': 'REACTOME',
#    'name': 'FCGR3A-mediated phagocytosis',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9664417',
#    'db_ns': 'REACTOME',
#    'name': 'Leishmania phagocytosis',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-9664407',
#    'db_ns': 'REACTOME',
#    'name': 'Parasite infection',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-388396',
#    'db_ns': 'REACTOME',
#    'name': 'GPCR downstream signalling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-375165',
#    'db_ns': 'REACTOME',
#    'name': 'NCAM signaling for neurite out-growth',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-373760',
#    'db_ns': 'REACTOME',
#    'name': 'L1CAM interactions',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-372790',
#    'db_ns': 'REACTOME',
#    'name': 'Signaling by GPCR',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-3371556',
#    'db_ns': 'REACTOME',
#    'name': 'Cellular response to heat stress',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-3371453',
#    'db_ns': 'REACTOME',
#    'name': 'Regulation of HSF1-mediated heat shock response',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-2871796',
#    'db_ns': 'REACTOME',
#    'name': 'FCERI mediated MAPK activation',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-2559585',
#    'db_ns': 'REACTOME',
#    'name': 'Oncogene Induced Senescence',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-2559583',
#    'db_ns': 'REACTOME',
#    'name': 'Cellular Senescence',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-2559582',
#    'db_ns': 'REACTOME',
#    'name': 'Senescence-Associated Secretory Phenotype (SASP)',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-2559580',
#    'db_ns': 'REACTOME',
#    'name': 'Oxidative Stress Induced Senescence',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-2454202',
#    'db_ns': 'REACTOME',
#    'name': 'Fc epsilon receptor (FCERI) signaling',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-2262752',
#    'db_ns': 'REACTOME',
#    'name': 'Cellular responses to stress',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-2173796',
#    'db_ns': 'REACTOME',
#    'name': 'SMAD2/SMAD3:SMAD4 heterotrimer regulates transcription',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-2173795',
#    'db_ns': 'REACTOME',
#    'name': 'Downregulation of SMAD2/3:SMAD4 transcriptional activity',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'R-HSA-2173793',
#    'db_ns': 'REACTOME',
#    'name': 'Transcriptional activity of SMAD2/SMAD3:SMAD4 heterotrimer',
#    'version': '87'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP75',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Toll like receptor signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP734',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Serotonin receptor 4 6 7 and NR3C signaling',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP732',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Serotonin receptor 2 and ELK SRF GATA4 signaling',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP722',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Serotonin HTR1 group and FOS pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP69',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'T cell receptor signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP673',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'ErbB signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP581',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'EPO receptor signaling',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5422',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'IL 19 signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5399',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'NPHP1 deletion syndrome',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5385',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Growth factors and hormones in Beta cell proliferation',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5373',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Role of hypoxia angiogenesis and FGF pathway in OA chondrocyte hypertrophy',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5366',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'NF1 copy number variation syndrome ',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5365',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': '4p16 3 copy number variation',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5353',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'A network map of Macrophage stimulating protein MSP signaling',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5347',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'IL 26 signaling pathways',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5346',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': '8p23 1 copy number variation syndrome',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5293',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Acute myeloid leukemia',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5269',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Genetic causes of porto sinusoidal vascular disease',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5221',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': '2q11 2 copy number variation syndrome',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5158',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Urotensin II mediated signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5144',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'NRP1 triggered signaling pathways in pancreatic cancer ',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5124',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Alzheimer 39 s disease',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP51',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Regulation of actin cytoskeleton',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5098',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'T cell activation SARS CoV 2',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5094',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Orexin receptor pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5087',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Pleural mesothelioma',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP5083',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Neuroinflammation and glutamatergic signaling',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP49',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'IL 2 signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4877',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Host pathogen interaction of human coronaviruses MAPK signaling',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4875',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Disruption of postsynaptic signaling by CNV',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4874',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'CAMKK2 pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4871',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Kisspeptin kisspeptin receptor system in the ovary',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP481',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Insulin signaling',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4806',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'EGFR tyrosine kinase inhibitor resistance',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4787',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Osteoblast differentiation and related diseases',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4767',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'FGFR3 signaling in chondrocyte proliferation and terminal differentiation',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4754',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'IL 18 signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4747',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Netrin UNC5B signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4685',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Melanoma',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4666',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Hepatitis B infection',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4659',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Gastrin signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4566',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Translation inhibitors in chronically activated PDGFRA cells',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4560',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'MFAP5 effect on permeability and motility of endothelial cells via cytoskeleton rearrangement',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4553',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'FBXL10 enhancement of MAP ERK signaling in diffuse large B cell lymphoma',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4539',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Synaptic signaling pathways associated with autism spectrum disorder',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4538',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Regulatory circuits of the STAT3 signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4535',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Envelope proteins and their potential roles in EDMD physiopathology',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4483',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Relationship between inflammation COX 2 and EGFR',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4481',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Resistin as a regulator of inflammation',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4389',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Bile acids synthesis and enterohepatic circulation ',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4341',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Non genomic actions of 1 25 dihydroxyvitamin D3',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4331',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Neovascularisation processes',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4301',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Inhibition of exosome biogenesis and secretion by Manumycin A in CRPC cells',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4298',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Acute viral myocarditis',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4263',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Pancreatic adenocarcinoma pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4262',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Breast cancer pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4255',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Non small cell lung cancer',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4239',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Epithelial to mesenchymal transition in colorectal cancer',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4223',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Ras signaling',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP422',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'MAPK cascade',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4217',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Ebola virus infection in host',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4216',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Chromosomal and microsatellite instability in colorectal cancer ',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4205',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'MET in type 1 papillary renal cell carcinoma',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4172',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'PI3K Akt signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP4155',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Endometrial cancer',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3995',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Prion disease pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP395',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'IL 4 signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3932',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Focal adhesion PI3K Akt mTOR signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3929',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Chemokine signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3915',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Angiopoietin like protein 8 regulatory pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3888',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'VEGFA VEGFR2 signaling',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3879',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': '4 hydroxytamoxifen dexamethasone and retinoic acids regulation of p27 expression',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3869',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Cannabinoid receptor signaling',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3859',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'TGF beta signaling in thyroid cells for epithelial mesenchymal transition',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP382',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'MAPK signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3668',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Hypothesized pathways in pathogenesis of cardiovascular disease',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP364',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'IL6 signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3303',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'RAC1 PAK1 p38 MMP2 pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP3301',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'MFAP5 mediated ovarian cancer cell motility and invasiveness',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP313',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Hepatocyte growth factor receptor signaling',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP306',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Focal adhesion',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP304',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Kit receptor signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2868',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'TCA cycle nutrient use and invasiveness of ovarian cancer',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP286',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'IL 3 signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2795',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Cardiac hypertrophic response',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2637',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Interleukin 1 IL 1 structural pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2636',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Common pathways underlying drug addiction',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP26',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'S1P receptor signal transduction',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2526',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'PDGF pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP244',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Alpha 6 beta 4 signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2431',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Spinal cord injury',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2380',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Brain derived neurotrophic factor BDNF signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2374',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Oncostatin M signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2355',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Corticotropin releasing hormone signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2332',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Interleukin 11 signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2324',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'AGE RAGE pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP231',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'TNF alpha signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2263',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Androgen receptor network in prostate cancer',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2261',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Glioblastoma signaling pathways',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2203',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Thymic stromal lymphopoietin TSLP signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP22',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'IL 9 signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2112',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'IL 17 signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2059',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Alzheimer 39 s disease and miRNA effects',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP205',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'IL 7 signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2037',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Prolactin signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2036',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'TNF related weak inducer of apoptosis TWEAK signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2035',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Follicle stimulating hormone FSH signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2034',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Leptin signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2032',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Thyroid stimulating hormone TSH signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP2018',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'RANKL RANK signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP1981',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Thyroxine thyroid hormone production',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP195',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'IL 1 signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP1544',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'MicroRNAs in cardiomyocyte hypertrophy',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP1434',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'Osteopontin signaling',
#    'version': '20240101'},
#   'labels': ['BioEntity']},
#  {'data': {'db_id': 'WP127',
#    'db_ns': 'WIKIPATHWAYS',
#    'name': 'IL 5 signaling pathway',
#    'version': '20240101'},
#   'labels': ['BioEntity']}]
